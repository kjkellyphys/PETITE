# %% [markdown]
# # PETITE SM shower generation example
#
# PETITE is a simple, lightweight, toy Monte Carlo that generates realistic electromagnetic showers.
#
# Authors: Kevin J. Kelly (Texas A&M), Nikita Blinov (U. Victoria), Ryan Plestid (Caltech), Patrick J. Fox (Fermilab), and Pedro A.M. Machado (Fermilab)
#
# It includes explicit simulation of (we denote nuclei by their electric charge $Z$)
#
# * Bremsstrahlung  $e^\pm Z \rightarrow e^\pm \gamma Z$.
# * Pair production $\gamma Z \rightarrow e^+ e^- Z$.
# * Compton scattering $\gamma e^- \rightarrow  \gamma e^-$
# * Pair-annihilation $e^+ e^- \rightarrow \gamma\gamma$
# * Moller Scattering $e^- e^- \rightarrow e^- e^-$
# * Bhabha Scattering $e^+ e^- \rightarrow e^+ e^-$
#
# and implicit simulation of
#
# * Multiple Coulomb scattering
# * Energy loss by ionization
#
# ${\bf Dependencies}$: numpy, vegas, pickle, cProfile, tqdm, scipy
#
# ${\bf Version~ requirements}$: numpy 1.24  ,  python3.xx with xx$\geq$9.
#
# ${\bf Directory~structure}$: This notebook assumes that within a PETITE home directory there is folder containing dictionaries, and that within that folder the following files exist
#
# * $\verb|<PETITE_home_dir>|$/$\verb|<dictionary_dir>|$/Feb13_xSec_Dicts.pkl
# * $\verb|<PETITE_home_dir>|$/$\verb|<dictionary_dir>|$/Mar24_xSec_Dicts.pkl
# * $\verb|<PETITE_home_dir>|$/$\verb|<dictionary_dir>|$/Mar24_xSec_Dicts_neval.pkl
#
# You can check versions with the code below and adjust if necessary

# %%
from platform import python_version
print("Python version: ", python_version())

import numpy
print("Numpy version: ", numpy.__version__)

import os
current_path = os.getcwd()
PETITE_home_dir= current_path.split('examples')[0]

print("PETITE home directory:", PETITE_home_dir)

dictionary_dir = "data/VEGAS_dictionaries/"
# Out:
# Python version:  3.10.11
# Numpy version:  1.25.0
# PETITE home directory: /Users/kjkelly/Documents/GitHub/PETITE/

# %% [markdown]
# ### Load in dependencies and set font styles

# %%
#from kjkutils import *
from PETITE.shower import *
import pickle as pk
from matplotlib import pyplot as plt
# from tqdm import tqdm
from tqdm import tqdm

import matplotlib

from matplotlib.font_manager import FontProperties
from matplotlib.ticker import FixedLocator, MaxNLocator
import cProfile
profile = cProfile.Profile()
import pstats

font0 = FontProperties()
font = font0.copy()
font.set_size(24)
font.set_family('serif')
labelfont=font0.copy()
labelfont.set_size(20)
labelfont.set_weight('bold')
legfont=font0.copy()
legfont.set_size(18)
legfont.set_weight('bold')


def set_size(w,h, ax=None):
    """ Helper function to set figure size.
        Input:
            w, h: width, height in inches """
    if not ax: ax=plt.gca()
    l = ax.figure.subplotpars.left
    r = ax.figure.subplotpars.right
    t = ax.figure.subplotpars.top
    b = ax.figure.subplotpars.bottom
    figw = float(w)/(r-l)
    figh = float(h)/(t-b)
    ax.figure.set_size_inches(figw, figh)

# %% [markdown]
# ####  Import two shower objects, one with a graphite target and one with lead. Both track down to minimum energies of 10 MeV
#
# The minimum energy in the shower dictates the run-time. As one attempts to simulate lower-threshold IR physics, the computational cost increases exponentially. The number of low energy particles proliferates and one encounters many compton scatters.  10 MeV allows for reasonable simulation speed.
#
# Pre-loaded materials are lead and graphite, but other materials can be included straightforwardly running other scripts in the PETITE utilities folder

# %%
# Shower(directory, material, minimum_energy)
sGraphite = Shower(PETITE_home_dir+dictionary_dir, "graphite", 0.010)
sLead = Shower(PETITE_home_dir+dictionary_dir, "lead", 0.010)

# %% [markdown]
# Now we create a list of energies to be used in the simulation.

# %%
EVec = np.logspace(np.log10(0.0015), np.log10(100.), 100)
EVec[58], EVec[73]
# Out:
# (1.0051239289306901, 5.4089737788907355)

# %% [markdown]
# ## Accept/reject in PETITE
# PETITE usese VEGAS intergrator objects pre-trained on a grid of incident particle energies. During a shower the nearest energy with ``good coverage'' is used to draw samples, and accept reject is performed with the diffential cross section at the true physical energy.
#
# As an illustration we set an incident electron energy at $E_{e} = 1.0 ~{\rm GeV}$, and sample from several integrators trained at nearby energies for the bremsstrahlung process $e Z \rightarrow e Z \gamma$.

# %%
number_of_samples = 1000
energy_in = 1.0

xs0 = []
trials0 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=45, process='Moller', VB=True)
    xs0.append(s0[0])
    trials0.append(s0[-1])

xs1 = []
trials1 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=48, process='Moller', VB=True)
    xs1.append(s0[0])
    trials1.append(s0[-1])

xs2 = []
trials2 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=51, process='Moller', VB=True)
    xs2.append(s0[0])
    trials2.append(s0[-1])

xs3 = []
trials3 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, process='Moller', LU_Key=-1, VB=True)
    xs3.append(s0[0])
    trials3.append(s0[-1])
# Out:
# 100%|██████████| 1000/1000 [00:00<00:00, 2756.71it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 2808.33it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3732.14it/s]
# 100%|██████████| 1000/1000 [00:00<00:00, 3277.66it/s]

# %% [markdown]
# ### Compare efficiency of sampling for different nearby energies

# %%
bin_space = np.linspace(0, 180, 181)
plt.hist(trials0, bins=bin_space, histtype='step', lw=1, label='LU=45')
plt.hist(trials1, bins=bin_space, histtype='step', lw=1, label='LU=48')
plt.hist(trials2, bins=bin_space, histtype='step', lw=1, label='LU=51')
plt.hist(trials3, bins=bin_space, histtype='step', lw=1, label='LU=-1')
plt.gca().set_xlabel(r"$N_{\rm draw}$")
plt.gca().set_ylabel(r"$\mathrm{Occurrence}$")
plt.gca().set_yscale('log')
# show labels
plt.legend()
# print number of trials
print("Number of trials: ", len(trials0), len(trials1), len(trials2), len(trials3))
# Out:
# Number of trials:  1000 1000 1000 1000

# %% [markdown]
# ### Check distributions to see if they are insensitive to choice of integrator object

# %%
plt.hist(xs0, bins=np.linspace(-1, 1, 101), histtype='step', lw=1)
plt.hist(xs1, bins=np.linspace(-1, 1, 101), histtype='step', lw=1)
plt.hist(xs2, bins=np.linspace(-1, 1, 101), histtype='step', lw=1)
plt.hist(xs3, bins=np.linspace(-1, 1, 101), histtype='step', lw=1)
plt.gca().set_xlabel(r"$x_1\ (E_{\gamma}\ \rm{proxy})$")
plt.gca().set_ylabel(r"$\mathrm{Occurrence}$")
plt.gca().set_yscale('log')

# %% [markdown]
# ## Use of rotated coordinates

# %% [markdown]
# PETITE uses small angle variables (see e.g. sections 92-94 of Landau and Lifshitz Vol 4). However low-momentum transfers occur along a correlated "ridge" in these variables. To improve performance we have rotated angles.
#
# We illustrate the difference in performance, and benchmark total cross sections computed using the VEGAS integrators below.

# %%
dicts_new_neval = pk.load(open(PETITE_home_dir+dictionary_dir+"sm_xsecs.pkl", "rb"))

# %% [markdown]
# ### Pair production
#
# Cross sections are material dependent due to $Z^2$ scaling, but also due to atomic form factors (see e.g.\ Tsai Rev. Mod. Phys. (1974).

# %%
#plt.plot(np.transpose(dicts_old['PairProd']['graphite'])[0], np.transpose(dicts_old['PairProd']['graphite'])[1]/6**2, color='dodgerblue', ls='-', label=r"$\mathrm{Original,\ graphite}$")
#plt.plot(np.transpose(dicts_new['PairProd']['graphite'])[0], np.transpose(dicts_new['PairProd']['graphite'])[1]/6**2, color='dodgerblue', ls='--', label=r"$\mathrm{Rotated/dimensionless,\ graphite}$")
plt.plot(np.transpose(dicts_new_neval['PairProd']['graphite'])[0], np.transpose(dicts_new_neval['PairProd']['graphite'])[1]/6**2, color='dodgerblue', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
#plt.plot(np.transpose(dicts_old['PairProd']['lead'])[0], np.transpose(dicts_old['PairProd']['lead'])[1]/82**2, color='coral', ls='-', label=r"$\mathrm{Original,\ lead}$")
#plt.plot(np.transpose(dicts_new['PairProd']['lead'])[0], np.transpose(dicts_new['PairProd']['lead'])[1]/82**2, color='coral', ls='--', label=r"$\mathrm{Rotated/dimensionless,\ lead}$")
plt.plot(np.transpose(dicts_new_neval['PairProd']['lead'])[0], np.transpose(dicts_new_neval['PairProd']['lead'])[1]/82**2, color='coral', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{\gamma}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma_{\rm pair\ prod.}/Z^2\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %% [markdown]
# ### Bremsstrahlung

# %%
#plt.plot(np.transpose(dicts_old['Brem']['graphite'])[0], np.transpose(dicts_old['Brem']['graphite'])[1]/6**2, color='dodgerblue', ls='-', label=r"$\mathrm{Original,\ graphite}$")
#plt.plot(np.transpose(dicts_new['Brem']['graphite'])[0], np.transpose(dicts_new['Brem']['graphite'])[1]/6**2, color='dodgerblue', ls='--', label=r"$\mathrm{Rotated/dimensionless,\ graphite}$")
plt.plot(np.transpose(dicts_new_neval['Brem']['graphite'])[0], np.transpose(dicts_new_neval['Brem']['graphite'])[1]/6**2, color='dodgerblue', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
#plt.plot(np.transpose(dicts_old['Brem']['lead'])[0], np.transpose(dicts_old['Brem']['lead'])[1]/82**2, color='coral', ls='-', label=r"$\mathrm{Original,\ lead}$")
#plt.plot(np.transpose(dicts_new['Brem']['lead'])[0], np.transpose(dicts_new['Brem']['lead'])[1]/82**2, color='coral', ls='--', label=r"$\mathrm{Rotated/dimensionless,\ lead}$")
plt.plot(np.transpose(dicts_new_neval['Brem']['lead'])[0], np.transpose(dicts_new_neval['Brem']['lead'])[1]/82**2, color='coral', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma_{\rm brem.}/Z^2\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
plt.plot(np.transpose(dicts_new_neval['Bhabha']['graphite'])[0], np.transpose(dicts_new_neval['Bhabha']['graphite'])[1], color='dodgerblue', ls='-.', label=r"$\mathrm{Bhabha}$")
plt.plot(np.transpose(dicts_new_neval['Moller']['graphite'])[0], np.transpose(dicts_new_neval['Moller']['graphite'])[1], color='coral', ls='-.', label=r"$\mathrm{Moller}$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
plt.plot(np.transpose(dicts_new_neval['Brem']['graphite'])[0], np.transpose(dicts_new_neval['Brem']['graphite'])[1], color='dodgerblue', ls='-', label=r"$\mathrm{Brem.}$")
plt.plot(np.transpose(dicts_new_neval['Moller']['graphite'])[0], np.transpose(dicts_new_neval['Moller']['graphite'])[1]*6, color='coral', ls='-', label=r"$\mathrm{Moller}\times 6$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
EVec = np.logspace(-3, 2, 101)
plt.plot(EVec, sGraphite._NSigmaBrem(EVec), ls='-', color='dodgerblue')
plt.plot(EVec, sGraphite._NSigmaMoller(EVec), ls='-', color='coral')
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %% [markdown]
# ## Shower production with PETITE
#
# The primary purpose of PETITE is to produce realistic electromagnetic showers with a lightweight, reasonably fast, python-native code base. We illustrate its performance below.
#
# We will shoot a 10 GeV particle incident on either lead or graphite. Particles are specified by their PDG codes (see e.g. https://pdg.lbl.gov/2007/reviews/montecarlorpp.pdf)
#
#
# * ${\rm PDG}(e^\pm)=\pm11$
# * ${\rm PDG}(\gamma)~~=+22$

# %%
E0 = 10.
p0_photon = [E0, 0, 0, E0]
p0_electron = [E0, 0, 0, np.sqrt(E0**2 - m_electron**2)]
r0 = [0., 0., 0.]
photon = Particle(p0_photon, r0, {"PID":22})
electron = Particle(p0_electron, r0, {"PID":11})

p0_pi0 = [E0, 0, 0, np.sqrt(E0**2 - m_pi0**2)]
pi0 = Particle(p0_pi0, r0, {"PID":111, "stability":"short-lived", "parent_PID":2212})

# %%
dists = []
E0samp = 10.0
for ki in tqdm(range(10000)):
    dists.append(sGraphite.sample_distance(-11, E0samp))
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       2 E0samp = 10.0
#       3 for ki in tqdm(range(10000)):
# ----> 4     dists.append(sGraphite.sample_distance(-11, E0samp))
#
# TypeError: Shower.sample_distance() takes 2 positional arguments but 3 were given

# %%
sGraphite.get_mfp(-11, E0samp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kjkelly/Documents/GitHub/PETITE/examples/shower_SM.ipynb Cell 29 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kjkelly/Documents/GitHub/PETITE/examples/shower_SM.ipynb#X40sZmlsZQ%3D%3D?line=0'>1</a> sGraphite.get_mfp(-11, E0samp)
#
# NameError: name 'E0samp' is not defined

# %%
mfp0 = sGraphite.get_mfp(-11, E0samp)
plt.hist(dists, histtype='step', bins=np.linspace(0, 4*mfp0, 101), density=True)
xs = np.linspace(0, 4*mfp0, 101)
ys = 1/mfp0*np.exp(-xs/mfp0)
plt.plot(xs, ys, color='k', ls='--')

# %% [markdown]
# Check shower timing

# %%
def slowShower():
    s0 = sGraphite.generate_shower(photon, VB=True)
    return

# %% [markdown]
# We use the package cProfile to return useful information on the runtime. This is helpful if one would like to change $E_{\rm min}$ which can slow down the code. The output below is helpful in diagnosing bottlenecks etc.

# %%
profileSS = cProfile.Profile()
profileSS.runcall(slowShower)
psSS = pstats.Stats(profileSS)
psSS.print_stats()
# Out:
# Starting shower, initial particle with ID Info
# {'PID': 22, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': None}
# Initial four-momenta:
# [10.0, 0, 0, 10.0]
#          2337221 function calls (2311274 primitive calls) in 1.010 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     14118    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       839    0.000    0.000    0.000    0.000 {method 'bit_length' of 'int' objects}
#      1770    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#     20025    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#      7437    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#      1069    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#      1071    0.002    0.000    0.002    0.000 {built-in method builtins.all}
#      7207    0.002    0.000    0.002    0.000 {built-in method builtins.getattr}
#     45339    0.003    0.000    0.003    0.000 {built-in method builtins.isinstance}
#     94535    0.006    0.000    0.006    0.000 {built-in method builtins.issubclass}
#     49078    0.003    0.000    0.003    0.000 {built-in method builtins.len}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#      4276    0.012    0.000    0.012    0.000 {built-in method builtins.round}
#         8    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         8    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/threading.py:553(is_set)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/threading.py:1102(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/threading.py:1169(is_alive)
#       839    0.000    0.000    0.000    0.000 {built-in method math.cos}
#       839    0.000    0.000    0.000    0.000 {built-in method math.log}
#       839    0.000    0.000    0.000    0.000 {built-in method math.sin}
#       839    0.000    0.000    0.000    0.000 {built-in method math.sqrt}
#      2517    0.000    0.000    0.000    0.000 {method 'random' of '_random.Random' objects}
#      1752    0.000    0.000    0.000    0.000 {method 'getrandbits' of '_random.Random' objects}
#       839    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/random.py:239(_randbelow_with_getrandbits)
#       839    0.000    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/random.py:375(choice)
#       839    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/random.py:546(uniform)
#      1678    0.002    0.000    0.002    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/random.py:591(gauss)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/zmq/sugar/socket.py:543(send)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/ipykernel/iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/ipykernel/iostream.py:202(schedule)
#         8    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/ipykernel/iostream.py:429(_is_master_process)
#         8    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/ipykernel/iostream.py:448(_schedule_flush)
#         8    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/ipykernel/iostream.py:518(write)
#      3207    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/multiarray.py:148(concatenate)
#      3816    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/multiarray.py:736(dot)
#      2138    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/multiarray.py:1071(copyto)
#      3207    0.001    0.000    0.006    0.000 <__array_function__ internals>:177(concatenate)
#      3816    0.001    0.000    0.008    0.000 <__array_function__ internals>:177(dot)
#      2138    0.001    0.000    0.004    0.000 <__array_function__ internals>:177(copyto)
#     46032    0.008    0.000    0.012    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/numerictypes.py:282(issubclass_)
#     23016    0.010    0.000    0.023    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/numerictypes.py:356(issubdtype)
#      1069    0.001    0.000    0.004    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/numeric.py:149(ones)
#      1069    0.001    0.000    0.003    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/numeric.py:289(full)
#      1908    0.001    0.000    0.002    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#      7437    0.002    0.000    0.002    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:70(<dictcomp>)
#      7437    0.007    0.000    0.026    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:69(_wrapreduction)
#       839    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:597(_transpose_dispatcher)
#       839    0.000    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:601(transpose)
#      1069    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1219(_argmin_dispatcher)
#      1069    0.001    0.000    0.002    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1223(argmin)
#     14119    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1961(_shape_dispatcher)
#     14119    0.003    0.000    0.004    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:1965(shape)
#      1069    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2155(_sum_dispatcher)
#      1069    0.001    0.000    0.006    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2160(sum)
#      2138    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2399(_all_dispatcher)
#      2138    0.001    0.000    0.007    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2404(all)
#      1069    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2670(_amax_dispatcher)
#      1069    0.001    0.000    0.005    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2675(amax)
#       839    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2795(_amin_dispatcher)
#       839    0.000    0.000    0.003    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2800(amin)
#      4460    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2965(_prod_dispatcher)
#      2322    0.001    0.000    0.010    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2970(prod)
#      2138    0.001    0.000    0.012    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3776(product)
#       839    0.000    0.000    0.002    0.000 <__array_function__ internals>:177(transpose)
#      1069    0.001    0.000    0.003    0.000 <__array_function__ internals>:177(argmin)
#     14119    0.004    0.000    0.015    0.000 <__array_function__ internals>:177(shape)
#      1069    0.000    0.000    0.007    0.000 <__array_function__ internals>:177(sum)
#      2138    0.001    0.000    0.009    0.000 <__array_function__ internals>:177(all)
#      1069    0.001    0.000    0.006    0.000 <__array_function__ internals>:177(amax)
#       839    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(amin)
#      2322    0.001    0.000    0.012    0.000 <__array_function__ internals>:177(prod)
#      2138    0.001    0.000    0.014    0.000 <__array_function__ internals>:177(product)
#      1770    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/core/getlimits.py:457(__new__)
#     22131    0.002    0.000    0.002    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/lib/type_check.py:206(_is_type_dispatcher)
#     22131    0.005    0.000    0.006    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/lib/type_check.py:303(iscomplexobj)
#     22131    0.006    0.000    0.018    0.000 <__array_function__ internals>:177(iscomplexobj)
#      1678    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/linalg/linalg.py:116(isComplexType)
#      1678    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/linalg/linalg.py:2345(_norm_dispatcher)
#      1678    0.003    0.000    0.006    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/linalg/linalg.py:2349(norm)
#      1678    0.001    0.000    0.007    0.000 <__array_function__ internals>:177(norm)
#     22131    0.002    0.000    0.002    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/lib/function_base.py:1428(_interp_dispatcher)
#     22131    0.011    0.000    0.039    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/lib/function_base.py:1432(interp)
#     22131    0.006    0.000    0.052    0.000 <__array_function__ internals>:177(interp)
#     22131    0.003    0.000    0.004    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/numpy/ma/core.py:6377(isMaskedArray)
#      8839    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:145(get_material_properties)
#      8138    0.012    0.000    0.197    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:231(get_mfp)
#      1069    0.007    0.000    0.007    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:269(<listcomp>)
#      1069    0.033    0.000    0.382    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:251(draw_sample)
#      1069    0.100    0.000    0.551    0.001 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:329(sample_scattering)
#       839    0.017    0.000    0.233    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:377(sample_distance)
#      1069    0.015    0.000    0.312    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:448(propagate_particle)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:547(<listcomp>)
#      1069    0.056    0.000    0.076    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:561(<listcomp>)
#         1    0.015    0.015    1.010    1.010 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:515(generate_shower)
#      1069    0.001    0.000    0.001    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#     23809    0.003    0.000    0.003    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     22131    0.004    0.000    0.004    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       839    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     18826    0.017    0.000    0.018    0.000 {built-in method numpy.array}
#     68071    0.007    0.000    0.007    0.000 {built-in method numpy.asarray}
#       839    0.001    0.000    0.001    0.000 {built-in method numpy.zeros}
#      2138    0.002    0.000    0.002    0.000 {built-in method numpy.empty}
# 80703/54756    0.034    0.000    0.114    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     22131    0.010    0.000    0.010    0.000 {built-in method numpy.core._multiarray_umath.interp}
#      7437    0.014    0.000    0.014    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     13050    0.004    0.000    0.004    0.000 {method 'random' of 'numpy.random.mtrand.RandomState' objects}
#      1069    0.017    0.000    0.020    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#     16322    0.022    0.000    0.022    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#     22131    0.006    0.000    0.058    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/scipy/interpolate/_interpolate.py:672(_call_linear_np)
#     22131    0.016    0.000    0.119    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/scipy/interpolate/_interpolate.py:745(_evaluate)
#     22131    0.043    0.000    0.043    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/scipy/interpolate/_interpolate.py:760(_check_bounds)
#     22131    0.026    0.000    0.061    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/scipy/_lib/_util.py:206(_asarray_validated)
#     22131    0.003    0.000    0.005    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/scipy/sparse/_base.py:1301(isspmatrix)
#     22131    0.012    0.000    0.211    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/scipy/interpolate/_polyint.py:58(__call__)
#     22131    0.008    0.000    0.071    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/scipy/interpolate/_polyint.py:89(_prepare_x)
#     22131    0.005    0.000    0.009    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/scipy/interpolate/_polyint.py:95(_finish_y)
#       839    0.003    0.000    0.003    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/moliere.py:150(get_chic_squared_alt)
#       839    0.003    0.000    0.003    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/moliere.py:165(get_chia_squared_alt)
#       839    0.005    0.000    0.014    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/moliere.py:215(generate_moliere_angle_simplified_alt)
#       839    0.012    0.000    0.014    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/moliere.py:237(get_rotation_matrix)
#       839    0.010    0.000    0.050    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/moliere.py:307(get_scattered_momentum)
#      2138    0.004    0.000    0.004    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:46(set_ids)
#      2138    0.003    0.000    0.026    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:8(__init__)
#     13286    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:55(get_ids)
#      2138    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:71(set_mass)
#      2138    0.005    0.000    0.017    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:73(set_p0)
#      6278    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:82(get_p0)
#      2834    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:84(set_pf)
#      5663    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:86(get_pf)
#      2138    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:89(set_r0)
#      1023    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:91(get_r0)
#      3161    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:93(set_rf)
#      2138    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:95(get_rf)
#      3208    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:98(set_ended)
#    602929    0.020    0.000    0.020    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:102(get_ended)
#      1069    0.014    0.000    0.014    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/particle.py:105(rotation_matrix)
#       639    0.008    0.000    0.010    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/kinematics.py:6(e_to_egamma_fourvecs)
#        88    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/kinematics.py:69(gamma_to_epem_fourvecs)
#        96    0.001    0.000    0.002    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/kinematics.py:105(compton_fourvecs)
#       228    0.003    0.000    0.003    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/kinematics.py:134(ee_to_ee_fourvecs)
#        18    0.000    0.000    0.000    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/kinematics.py:160(annihilation_fourvecs)
#     22166    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:13(unity)
#     22166    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:16(dummy)
#       478    0.002    0.000    0.003    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:19(pair_production_q_sq_dimensionless)
#      3456    0.013    0.000    0.024    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:36(brem_q_sq_dimensionless)
#      5496    0.001    0.000    0.001    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:68(aa)
#      5496    0.005    0.000    0.005    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:73(g2_elastic)
#      1728    0.019    0.000    0.025    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:106(dsigma_brem_dimensionless)
#       783    0.005    0.000    0.007    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:301(dsigma_annihilation_dCT)
#       239    0.002    0.000    0.003    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:343(dsigma_pairprod_dimensionless)
#      3210    0.037    0.000    0.043    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:390(dsigma_compton_dCT)
#      3628    0.016    0.000    0.022    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:438(dsigma_moller_dCT)
#      3462    0.024    0.000    0.030    0.000 /Users/kjkelly/Documents/miniforge3/envs/kjk/lib/python3.10/site-packages/PETITE/all_processes.py:459(dsigma_bhabha_dCT)
#      1069    0.005    0.000    0.005    0.000 _vegas.pyx:310(map)
#      1069    0.017    0.000    0.035    0.000 _vegas.pyx:467(adapt)
#      2138    0.000    0.000    0.000    0.000 _vegas.pyx:596(clear)
#      1069    0.036    0.000    0.094    0.000 _vegas.pyx:1162(set)
#      2138    0.018    0.000    0.033    0.000 _vegas.pyx:1471(random_batch)
#     14119    0.004    0.000    0.044    0.000 _vegas.pyx:1612(random)
#         1    0.000    0.000    1.010    1.010 /var/folders/f7/2f10v0150kq5wjxpbj74ph000000gp/T/ipykernel_30292/4104204086.py:1(slowShower)
#     13050    0.001    0.000    0.001    0.000 stringsource:563(__get__)
#      1069    0.004    0.000    0.117    0.000 _vegas.pyx:1113(__init__)
#     23518    0.001    0.000    0.001    0.000 stringsource:663(memoryview_check)
#     23518    0.004    0.000    0.008    0.000 stringsource:657(memoryview_cwrapper)
#     51534    0.007    0.000    0.007    0.000 stringsource:345(__cinit__)
#      1069    0.010    0.000    0.014    0.000 _vegas.pyx:113(__init__)
#      1069    0.000    0.000    0.001    0.000 _vegas.pxd:29(__get__)
#     28016    0.009    0.000    0.013    0.000 stringsource:999(memoryview_fromslice)
#     28016    0.001    0.000    0.001    0.000 stringsource:559(__get__)
#     24809    0.001    0.000    0.001    0.000 stringsource:518(__getbuffer__)
#     28016    0.002    0.000    0.002    0.000 stringsource:976(__dealloc__)
#     51534    0.005    0.000    0.005    0.000 stringsource:372(__dealloc__)
#      1069    0.000    0.000    0.001    0.000 _vegas.pxd:28(__get__)
#      1069    0.000    0.000    0.001    0.000 _vegas.pxd:27(__get__)
#      2138    0.000    0.000    0.000    0.000 _vegas.pyx:142(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:39(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:39(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:42(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:42(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:41(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:41(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:43(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:43(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:44(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:44(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:45(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:45(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:46(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:46(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:47(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:47(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:49(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:49(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:54(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:54(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:55(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:55(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:52(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:52(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:53(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:53(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:60(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:60(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:50(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:50(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:51(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:51(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:56(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:56(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:57(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:57(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:58(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:58(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:59(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:59(__set__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:61(__get__)
#      1069    0.000    0.000    0.000    0.000 _vegas.pxd:61(__set__)
#     36946    0.010    0.000    0.023    0.000 stringsource:403(__getitem__)
#     36946    0.004    0.000    0.004    0.000 stringsource:666(_unellipsify)
#     36946    0.004    0.000    0.008    0.000 stringsource:393(get_item_pointer)
#     36946    0.004    0.000    0.004    0.000 stringsource:910(pybuffer_index)
#     28736    0.001    0.000    0.001    0.000 stringsource:979(convert_item_to_object)
#      1069    0.000    0.000    0.000    0.000 stringsource:605(__len__)

# %% [markdown]
# ### Generate showers for graphite and lead
#
# The following code generates a shower initiated by a 10 GeV electron.  To see how functions work you may call their docstrings

# %%
print(sGraphite.generate_shower.__doc__)
# Out:
#         Generates particle shower from an initial particle
#         Args:
#             PID0: PDG ID of the initial particle
#             p40: four-momentum of the initial particle
#             ParID: PDG ID of the parent of the initial particle
#             VB: bool to turn on/off verbose output
#
#         Returns:
#             AllParticles: a list of all particles generated in the shower

# %% [markdown]
# ####  You supply a "parent" for the initial electron. PETITE thinks of each particle as a successive daughter of its ancestors. We supply a parent particle as a photon, but this does not influence the generation of the shower

# %%
#SMS = sGraphite.generate_shower(electron, VB=True)
#SMSLead = sLead.generate_shower(electron, VB=True)

SMS = sGraphite.generate_shower(pi0, VB=True)
SMSLead = sLead.generate_shower(pi0, VB=True)
# Out:
# Starting shower, initial particle with ID Info
# {'PID': 111, 'ID': 0, 'parent_PID': 2212, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.134977, 'stability': 'short-lived'}
# Initial four-momenta:
# [10.0, 0, 0, 9.999089021679012]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 4
#       1 #SMS = sGraphite.generate_shower(electron, VB=True)
#       2 #SMSLead = sLead.generate_shower(electron, VB=True)
# ----> 4 SMS = sGraphite.generate_shower(pi0, VB=True)
#       5 SMSLead = sLead.generate_shower(pi0, VB=True)
#
# File ~/miniconda3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:558, in Shower.generate_shower(self, p0, VB, GlobalMS)
#     556 elif np.abs(ap.get_ids()["PID"]) == 11:
#     557     dEdxT = self.get_material_properties()[3]*(0.1) #Converting MeV/cm to GeV/m
# --> 558     ap = self.propagate_particle(ap, MS=MS_e, Losses=dEdxT)
#     560 all_particles[apI] = ap
#     562 if (all([apC.get_ended() == True for apC in all_particles]) is True and ap.get_pf()[0] < self.min_energy):
#
# File ~/miniconda3/envs/kjk/lib/python3.10/site-packages/PETITE/shower.py:472, in Shower.propagate_particle(self, Part0, Losses, MS)
#     470     dist = mfp*np.log(1.0/(1.0-distC))
#     471 else:
# --> 472     dist = self.sample_distance(Part0.get_ids()["PID"], Part0.get_p0()[0])
#     473 M0 = Part0.get_ids()["mass"]
#     474 #if np.abs(Part0.get_ids()["PID"]) == 11:
#     475 #    M0 = m_electron
#     476 #elif Part0.get_ids()["PID"] == 22:
#     477 #    M0 = 0.0
#
# TypeError: Shower.sample_distance() takes 2 positional arguments but 3 were given

# %% [markdown]
# ### Get all the photons, electrons, and positrons in the shower
#
# We take the array from graphite SMS, and we find all the particles that match the relevant PID

# %%
SMSPhotons = np.array(SMS)[np.where([ps.get_ids()["PID"] == 22 for ps in SMS])[0]]
SMSPhotonsLead = np.array(SMSLead)[np.where([ps.get_ids()["PID"] == 22 for ps in SMSLead])[0]]
SMSElectrons = np.array(SMS)[np.where([ps.get_ids()["PID"] == 11 for ps in SMS])[0]]
SMSPositrons = np.array(SMS)[np.where([ps.get_ids()["PID"] == -11 for ps in SMS])[0]]

# %%
PhotonEs = np.array([s.get_p0()[0] for s in SMSPhotons])
PhotonEsLead = np.array([s.get_p0()[0] for s in SMSPhotonsLead])

# %%
ElectronEs = np.array([s.get_p0()[0] for s in SMSElectrons])
PositronEs = np.array([s.get_p0()[0] for s in SMSPositrons])

# %%
len(PhotonEs)
# Out:
# 178

# %% [markdown]
# ### Plot the integrated distribution of photons in a shower with respect to their energy

# %%
b0 = np.logspace(-3, 1, 41)

plt.hist(PhotonEs, bins=b0, histtype='step', lw=3, color='C6', density=True, ls='-', label=r"$\mathrm{SM,\ Graphite}$")
plt.hist(PhotonEsLead, bins=b0, histtype='step', lw=3, color='C6', density=True, ls='--', label=r"$\mathrm{SM,\ Lead}$")

plt.gca().legend(loc=1, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_\gamma\ [\mathrm{GeV}]$", fontsize=24)
plt.gca().set_ylabel(r"$\mathrm{photons/bin}$", fontsize=24)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(16) for l in plt.gca().get_xticklabels()]
[l.set_size(16) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %%
b0 = np.logspace(-3, 1, 41)

plt.hist(ElectronEs, bins=b0, histtype='step', lw=3, color='C4', density=True, ls='-', label=r"$\mathrm{SM,\ } e^-$")
plt.hist(PositronEs, bins=b0, histtype='step', lw=3, color='C4', density=True, ls='--', label=r"$\mathrm{SM,\ } e^+$")

plt.gca().legend(loc=1, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_\gamma\ [\mathrm{GeV}]$", fontsize=24)
plt.gca().set_ylabel(r"$\mathrm{electrons/bin}$", fontsize=24)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(16) for l in plt.gca().get_xticklabels()]
[l.set_size(16) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ## Event displays
#
# PETITE can be used to produce event displays for electromagnetic showers. The relevant loop of code (beyond plotting aesthetics) is highlighted below.
#
# Each event in the shower contains information on its location of "production" $\mathbf{r}_0$ and its location of "destruction" $\mathbf{r}_f$. Here, production and destruction only refer to being tracked in the simulation. For example, an atomic electron that is ionized by compton scattering with energy above $10~{\rm MeV}$ is "produced", and a $12~{\rm MeV}$ electron that looses $4 ~{\rm MeV}$ of energy falls below the $10~{\rm MeV}$ threshold of the simulation and is "destroyed".

# %%
print("The location of production for particle 12:", SMS[12].get_r0())
print("The location of destruction for particle 12:", SMS[12].get_rf())
# Out:
# The location of production for particle 12: [-4.11220002465045e-06, -1.4013198383477939e-05, 0.05321355554969444]
# The location of destruction for particle 12: [0.0001145227214057636, 5.110509443382837e-05, 0.4008273291375019]

# %% [markdown]
# ### We can use these function to make event displays
#
# The particles in SMS are sorted by their PID, and plotted as either squiggly green lines (photons), straight red lines (electrons) or straight blue lines (positrons).

# %%
figwid = 6.0*2.0
fighei = 6.0*0.5
lside = 3.0
rside = 3.5
wwspace = 1.25

ncol = 1
nrow = 2

wid = lside + ncol*figwid + (ncol-1)*wwspace + rside

bot = 3.77
top = 3.5
hhspace = 0.25

hei = bot + nrow*fighei + (nrow-1)*hhspace + top

lfactor = lside/wid
rfactor = rside/wid
bfactor = bot/hei
tfactor = top/hei
wfactor = wwspace/figwid
hfactor = hhspace/fighei

matplotlib.rcParams['axes.linewidth'] = 2.0
fig, axes = plt.subplots(nrow, ncol, figsize=(wid, hei), facecolor='1.0');
fig.subplots_adjust(left = lfactor, bottom=bfactor, right=(1.0-rfactor), top=(1.0-tfactor), wspace=wfactor, hspace=hfactor);

xmin, xmax, ymin, ymax = -0.02, 2, -0.04, 0.04
#xmin, xmax, ymin, ymax = -1.0, 5.0, -0.4, 0.4

ax = axes[0]
ax.axis([xmin, xmax, ymin, ymax])
ax.plot([xmin, xmin, xmax, xmax, xmin], [ymin, ymax, ymax, ymin, ymin], ls='-', color='k', lw=4, zorder=50)
#ax.set_xlabel(r'$z\ [\mathrm{m}]$', fontproperties=font)        
ax.set_ylabel(r'$x\ [\mathrm{m}]$', fontproperties=font)        

ax.tick_params(direction='in', zorder=30, length=20, width=2)
ax.tick_params(direction='in', which='minor', zorder=30, length=15, width=1.5)
[l.set_position((0.5, -0.015)) for l in ax.get_xticklabels()]
[l.set_size((0)) for l in ax.get_xticklabels()]
[l.set_size((labelfont.get_size())) for l in ax.get_yticklabels()]

for ki0 in SMS:
    ki = np.concatenate([ki0.get_r0(), ki0.get_rf()])
    if ki0.get_ids()["PID"] == 22:
        with matplotlib.rc_context({'path.sketch': (5, 15, 1)}):
            ax.plot([ki[2], ki[5]], [ki[0], ki[3]], lw=1, ls='-', color='g', alpha=0.5)
    if ki0.get_ids()["PID"] == 11:
        ax.plot([ki[2], ki[5]], [ki[0], ki[3]], lw=1, ls='-', color='r', alpha=0.5)
    if ki0.get_ids()["PID"] == -11:
        ax.plot([ki[2], ki[5]], [ki[0], ki[3]], lw=1, ls='-', color='b', alpha=0.5)

ax = axes[1]
ax.axis([xmin, xmax, ymin, ymax])
ax.plot([xmin, xmin, xmax, xmax, xmin], [ymin, ymax, ymax, ymin, ymin], ls='-', color='k', lw=4, zorder=50)
ax.set_xlabel(r'$z\ [\mathrm{m}]$', fontproperties=font)        
ax.set_ylabel(r'$y\ [\mathrm{m}]$', fontproperties=font)        

ax.tick_params(direction='in', zorder=30, length=20, width=2)
ax.tick_params(direction='in', which='minor', zorder=30, length=15, width=1.5)
[l.set_position((0.5, -0.015)) for l in ax.get_xticklabels()]
[l.set_size((labelfont.get_size())) for l in ax.get_xticklabels()]
[l.set_size((labelfont.get_size())) for l in ax.get_yticklabels()]

for ki0 in SMS:
    ki = np.concatenate([ki0.get_r0(), ki0.get_rf()])
    if ki0.get_ids()["PID"] == 22:
        with matplotlib.rc_context({'path.sketch': (5, 15, 1)}):
            ax.plot([ki[2], ki[5]], [ki[1], ki[4]], lw=1, ls='-', color='g', alpha=0.5)
    if ki0.get_ids()["PID"] == 11:
        ax.plot([ki[2], ki[5]], [ki[1], ki[4]], lw=1, ls='-', color='r', alpha=0.5)
    if ki0.get_ids()["PID"] == -11:
        ax.plot([ki[2], ki[5]], [ki[1], ki[4]], lw=1, ls='-', color='b', alpha=0.5)

# %% [markdown]
# ### Comparison of lead vs graphite

# %%
figwid = 6.0*2.0
fighei = 6.0*0.5
lside = 3.0
rside = 3.5
wwspace = 1.25

ncol = 2
nrow = 2

wid = lside + ncol*figwid + (ncol-1)*wwspace + rside

bot = 3.77
top = 3.5
hhspace = 0.25

hei = bot + nrow*fighei + (nrow-1)*hhspace + top

lfactor = lside/wid
rfactor = rside/wid
bfactor = bot/hei
tfactor = top/hei
wfactor = wwspace/figwid
hfactor = hhspace/fighei

matplotlib.rcParams['axes.linewidth'] = 2.0
fig, axes = plt.subplots(nrow, ncol, figsize=(wid, hei), facecolor='1.0');
fig.subplots_adjust(left = lfactor, bottom=bfactor, right=(1.0-rfactor), top=(1.0-tfactor), wspace=wfactor, hspace=hfactor);

xmin, xmax, ymin, ymax = -0.02, 2, -0.05, 0.05
#xmin, xmax, ymin, ymax = -1.0, 5.0, -0.4, 0.4

ax = axes[0][0]
ax.axis([xmin, xmax, ymin, ymax])
ax.plot([xmin, xmin, xmax, xmax, xmin], [ymin, ymax, ymax, ymin, ymin], ls='-', color='k', lw=4, zorder=50)
#ax.set_xlabel(r'$z\ [\mathrm{m}]$', fontproperties=font)        
ax.set_ylabel(r'$x\ [\mathrm{m}]$', fontproperties=font)        
ax.set_title(r"$\mathrm{Graphite}$", fontproperties=font)

ax.tick_params(direction='in', zorder=30, length=20, width=2)
ax.tick_params(direction='in', which='minor', zorder=30, length=15, width=1.5)
[l.set_position((0.5, -0.015)) for l in ax.get_xticklabels()]
[l.set_size((0)) for l in ax.get_xticklabels()]
[l.set_size((labelfont.get_size())) for l in ax.get_yticklabels()]

for ki0 in SMS:
    ki = np.concatenate([ki0.get_r0(), ki0.get_rf()])
    if ki0.get_ids()["PID"] == 22:
        with matplotlib.rc_context({'path.sketch': (5, 15, 1)}):
            ax.plot([ki[2], ki[5]], [ki[0], ki[3]], lw=1, ls='-', color='mediumseagreen', alpha=0.5)
    if ki0.get_ids()["PID"] == 11:
        ax.plot([ki[2], ki[5]], [ki[0], ki[3]], lw=1, ls='-', color='coral', alpha=0.5)
    if ki0.get_ids()["PID"] == -11:
        ax.plot([ki[2], ki[5]], [ki[0], ki[3]], lw=1, ls='-', color='dodgerblue', alpha=0.5)

ax = axes[1][0]
ax.axis([xmin, xmax, ymin, ymax])
ax.plot([xmin, xmin, xmax, xmax, xmin], [ymin, ymax, ymax, ymin, ymin], ls='-', color='k', lw=4, zorder=50)
ax.set_xlabel(r'$z\ [\mathrm{m}]$', fontproperties=font)        
ax.set_ylabel(r'$y\ [\mathrm{m}]$', fontproperties=font)        

ax.tick_params(direction='in', zorder=30, length=20, width=2)
ax.tick_params(direction='in', which='minor', zorder=30, length=15, width=1.5)
[l.set_position((0.5, -0.015)) for l in ax.get_xticklabels()]
[l.set_size((labelfont.get_size())) for l in ax.get_xticklabels()]
[l.set_size((labelfont.get_size())) for l in ax.get_yticklabels()]

for ki0 in SMS:
    ki = np.concatenate([ki0.get_r0(), ki0.get_rf()])
    if ki0.get_ids()["PID"] == 22:
        with matplotlib.rc_context({'path.sketch': (5, 15, 1)}):
            ax.plot([ki[2], ki[5]], [ki[1], ki[4]], lw=1, ls='-', color='mediumseagreen', alpha=0.5)
    if ki0.get_ids()["PID"] == 11:
        ax.plot([ki[2], ki[5]], [ki[1], ki[4]], lw=1, ls='-', color='coral', alpha=0.5)
    if ki0.get_ids()["PID"] == -11:
        ax.plot([ki[2], ki[5]], [ki[1], ki[4]], lw=1, ls='-', color='dodgerblue', alpha=0.5)


xmin, xmax, ymin, ymax = -0.02, 0.2, -0.05, 0.05


ax = axes[0][1]
ax.axis([xmin, xmax, ymin, ymax])
ax.plot([xmin, xmin, xmax, xmax, xmin], [ymin, ymax, ymax, ymin, ymin], ls='-', color='k', lw=4, zorder=50)
#ax.set_xlabel(r'$z\ [\mathrm{m}]$', fontproperties=font)        
ax.set_ylabel(r'$x\ [\mathrm{m}]$', fontproperties=font)        
ax.set_title(r"$\mathrm{Lead}$", fontproperties=font)

ax.tick_params(direction='in', zorder=30, length=20, width=2)
ax.tick_params(direction='in', which='minor', zorder=30, length=15, width=1.5)
[l.set_position((0.5, -0.015)) for l in ax.get_xticklabels()]
[l.set_size((0)) for l in ax.get_xticklabels()]
[l.set_size((labelfont.get_size())) for l in ax.get_yticklabels()]

for ki0 in SMSLead:
    ki = np.concatenate([ki0.get_r0(), ki0.get_rf()])
    if ki0.get_ids()["PID"] == 22:
        with matplotlib.rc_context({'path.sketch': (5, 15, 1)}):
            ax.plot([ki[2], ki[5]], [ki[0], ki[3]], lw=1, ls='-', color='mediumseagreen', alpha=0.5)
    if ki0.get_ids()["PID"] == 11:
        ax.plot([ki[2], ki[5]], [ki[0], ki[3]], lw=1, ls='-', color='coral', alpha=0.5)
    if ki0.get_ids()["PID"] == -11:
        ax.plot([ki[2], ki[5]], [ki[0], ki[3]], lw=1, ls='-', color='dodgerblue', alpha=0.5)

ax = axes[1][1]
ax.axis([xmin, xmax, ymin, ymax])
ax.plot([xmin, xmin, xmax, xmax, xmin], [ymin, ymax, ymax, ymin, ymin], ls='-', color='k', lw=4, zorder=50)
ax.set_xlabel(r'$z\ [\mathrm{m}]$', fontproperties=font)        
ax.set_ylabel(r'$y\ [\mathrm{m}]$', fontproperties=font)        

ax.tick_params(direction='in', zorder=30, length=20, width=2)
ax.tick_params(direction='in', which='minor', zorder=30, length=15, width=1.5)
[l.set_position((0.5, -0.015)) for l in ax.get_xticklabels()]
[l.set_size((labelfont.get_size())) for l in ax.get_xticklabels()]
[l.set_size((labelfont.get_size())) for l in ax.get_yticklabels()]

for ki0 in SMSLead:
    ki = np.concatenate([ki0.get_r0(), ki0.get_rf()])
    if ki0.get_ids()["PID"] == 22:
        with matplotlib.rc_context({'path.sketch': (5, 15, 1)}):
            ax.plot([ki[2], ki[5]], [ki[1], ki[4]], lw=1, ls='-', color='mediumseagreen', alpha=0.5)
    if ki0.get_ids()["PID"] == 11:
        ax.plot([ki[2], ki[5]], [ki[1], ki[4]], lw=1, ls='-', color='coral', alpha=0.5)
    if ki0.get_ids()["PID"] == -11:
        ax.plot([ki[2], ki[5]], [ki[1], ki[4]], lw=1, ls='-', color='dodgerblue', alpha=0.5)

for ax in axes[0]:
    ax.plot([0, 2.2, 2.2, 0, 0], [0.008, 0.008, -0.008, -0.008, 0.008], lw=1, color='k', ls='-', alpha=0.5)
for ax in axes[1]:
    ax.plot([0, 2.2, 2.2, 0, 0], [0.008, 0.008, -0.008, -0.008, 0.008], lw=1, color='k', ls='-', alpha=0.5)

# %% [markdown]
# ## Tests and validations
#
# Generate some ensembles of brem./pair production samples, with 10 GeV particles injected and check basic properties of distributions

# %%
nSamp = 200000
s0 = np.array([sGraphite.sample_scattering(electron, process="Brem", VB=True) for i in tqdm(range(nSamp))])
s0G = np.array([sGraphite.sample_scattering(photon, process="PairProd", VB=True) for i in tqdm(range(nSamp))])
# Out:
#   0%|          | 0/200000 [00:00<?, ?it/s]
# 100%|██████████| 200000/200000 [01:03<00:00, 3144.50it/s]
# 100%|██████████| 200000/200000 [00:53<00:00, 3759.14it/s]

# %%
Es = np.array([s[1].get_p0()[0] for s in s0])
EsE = np.array([s[0].get_p0()[0] for s in s0])

EsG = np.array([s[1].get_p0()[0] for s in s0G])
EsGP = np.array([s[0].get_p0()[0] for s in s0G])

# %% [markdown]
# ### Photon and electron distribution from first scatter
#
# We expect a flat photon distribution in log-space

# %%
b0 = np.logspace(-3, 1, 41)

dens = False
plt.hist(Es, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\mathrm{SM,\ Ryan\ Approach}$")
plt.hist(EsE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--')

#plt.gca().legend(loc='best', fontsize=16, framealpha=1.0)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_\gamma\ \mathrm{or}\ E_{e^-}\ [\mathrm{GeV}]$", fontsize=24)
plt.gca().set_ylabel(r"$\mathrm{particles/bin}$", fontsize=24)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(16) for l in plt.gca().get_xticklabels()]
[l.set_size(16) for l in plt.gca().get_yticklabels()]

set_size(8.0, 5.0)

# %% [markdown]
# ### Look at angular distributions of outgoing particles from bremsstrahlung/pair production in terms of their $p_T/p_z$

# %%
pTpz = np.array([(s[1].get_p0()[3]/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0])
pTpzE = np.array([(s[0].get_p0()[3]/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0])

pTpzG = np.array([(s[1].get_p0()[3]/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0G])
pTpzGP = np.array([(s[0].get_p0()[3]/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0G])

# %%
pT = np.array([(1/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0])
pTE = np.array([(1/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0])

pTG = np.array([(1/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0G])
pTGP = np.array([(1/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0G])

# %%
b0 = np.logspace(-10, 2, 41)

dens = True
plt.hist(pTpz, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\gamma,\ \rm{brem.}$")
plt.hist(pTpzE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--', label=r"$e^{-},\ \rm{brem.}$")

plt.hist(pTpzG, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='-', label=r"$e^{-},\ \rm{pair\ prod.}$")
plt.hist(pTpzGP, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='--', label=r"$e^{+},\ \rm{pair\ prod.}$")

plt.gca().legend(loc='best', fontsize=16, framealpha=1.0)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$p_T/p_z$", fontsize=24)
plt.gca().set_ylabel(r"$dN/d(p_T/p_z)$", fontsize=24)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(16) for l in plt.gca().get_xticklabels()]
[l.set_size(16) for l in plt.gca().get_yticklabels()]

set_size(8.0, 5.0)

# %%
b0 = np.logspace(-10, 2, 41)

dens = True
plt.hist(pT, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\gamma,\ \rm{brem.}$")
plt.hist(pTE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--', label=r"$e^{-},\ \rm{brem.}$")

plt.hist(pTG, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='-', label=r"$e^{-},\ \rm{pair\ prod.}$")
plt.hist(pTGP, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='--', label=r"$e^{+},\ \rm{pair\ prod.}$")

plt.gca().legend(loc='best', fontsize=16, framealpha=1.0)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$p_T\ [\mathrm{GeV}]$", fontsize=24)
plt.gca().set_ylabel(r"$dN/d(p_T)$", fontsize=24)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(16) for l in plt.gca().get_xticklabels()]
[l.set_size(16) for l in plt.gca().get_yticklabels()]

set_size(8.0, 5.0)

# %% [markdown]
# ## Outgoing electron/positron energies coming from pair production: should be identical

# %%
b0 = np.logspace(-4, 2, 41)

dens=False 

plt.hist(EsG, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-')
plt.hist(EsGP, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--')

#plt.gca().legend(loc=2, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_{e^\pm}\ [\mathrm{GeV}]$", fontsize=24)
plt.gca().set_ylabel(r"$\mathrm{photons/bin}$", fontsize=24)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(16) for l in plt.gca().get_xticklabels()]
[l.set_size(16) for l in plt.gca().get_yticklabels()]

set_size(8.0, 5.0)

# %% [markdown]
# ### Event-by-event ratio of $E_{e^-}/E_{e^+}$: should be symmetric about 1.

# %%
b0 = np.logspace(-4, 4, 61)

plt.hist(EsG/EsGP, bins=b0, histtype='step', lw=3, color='C6', density=False, ls='-', label=r"$\mathrm{SM,\ Ryan\ Approach}$")

#plt.gca().legend(loc=1, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_{e^-}/E_{e^+}$", fontsize=24)
plt.gca().set_ylabel(r"$\mathrm{simulations}$", fontsize=24)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(16) for l in plt.gca().get_xticklabels()]
[l.set_size(16) for l in plt.gca().get_yticklabels()]
plt.gca().axvline(1.0, color='k', lw=1, ls='--')

set_size(8.0, 5.0)

# %% [markdown]
# ### Asymmetry of the distribution.
#
# A basic test is distributions should be symmetric under  $e^+\leftrightarrow e^-$. We expect deviations due to statistical flucutations, on the order of $1/\sqrt{N}$ where $N$ is the size of the sample.

# %%
print("Asyymetry", (len(np.where(EsG > E0/2)[0]) - len(np.where(EsG < E0/2)[0]))/len(EsG) ) 
print("Statistical Error:" , 1/np.sqrt(len(EsG)) )
# Out:
# Asyymetry 0.00636
# Statistical Error: 0.00223606797749979
