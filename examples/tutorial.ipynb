# %% [markdown]
# # PETITE Tutorial
# Authors: Kevin J. Kelly (Texas A&M), Nikita Blinov (U. Victoria), Ryan Plestid (Caltech), Patrick J. Fox (Fermilab), and Pedro A. N. Machado (Fermilab)
#
# PETITE is a simple, lightweight, toy Monte Carlo that generates realistic electromagnetic showers, with or without new physics.
# Currently, dark photons with pure vector couplins are incorporated in PETITE.
#
# PETITE includes explicit simulation of (we denote nuclei by their electric charge $Z$)
#
# * Bremsstrahlung  $e^\pm Z \rightarrow e^\pm \gamma Z$.
# * Pair production $\gamma Z \rightarrow e^+ e^- Z$.
# * Compton scattering $\gamma e^- \rightarrow  \gamma e^-$
# * Pair-annihilation $e^+ e^- \rightarrow \gamma\gamma$
# * Moller Scattering $e^- e^- \rightarrow e^- e^-$
# * Bhabha Scattering $e^+ e^- \rightarrow e^+ e^-$
#
# and implicit simulation of
#
# * Multiple Coulomb scattering
# * Energy loss by ionization
#
# ${\bf Dependencies}$: numpy, vegas, pickle, cProfile, tqdm, scipy
#
# ${\bf Version~ requirements}$: numpy 1.24  ,  python3.xx with xx$\geq$9.
#
# ${\bf Directory~structure}$: This notebook assumes that within a PETITE home directory there is folder containing dictionaries, and that within that folder the following files exist
#
# * $\verb|<PETITE_home_dir>|$/$\verb|<dictionary_dir>|$/sm_xsec.pkl
# * $\verb|<PETITE_home_dir>|$/$\verb|<dictionary_dir>|$/sm_maps.pkl
#
# You can check versions with the code below and adjust if necessary.
#
# In this tutorial you will learn how to
# 1. Initialize PETITE
# 2. Generate a standard electromagnetic shower
# 3. Generate a shower with a dark photon
# 4. Analyze the accept/reject method used by PETITE, based on precomputed shower samples
# 5. Understand how to generate novel shower samples.

# %%
# Force reload (if changes have been made to the module)
# %load_ext autoreload
# %autoreload 2

# Initialization of the tutorial
from platform import python_version
print("Python version: ", python_version())

import numpy
print("Numpy version: ", numpy.__version__)

import os
current_path = os.getcwd()
PETITE_home_dir= current_path.split('examples')[0]

print("PETITE home directory:", PETITE_home_dir)
# folder where VEGAS dictionaries are stored
# dictionary_dir = "data/VEGAS_dictionaries/"
dictionary_dir = "data/"
# Out:
# Python version:  3.8.10
# Numpy version:  1.24.2
# PETITE home directory: /home/pedro/projects/PETITE/

# %% [markdown]
# ### Load in dependencies and set font styles

# %%
from PETITE.shower import *
import pickle as pk
from matplotlib import pyplot as plt
from tqdm import tqdm
#from tqdm.notebook import tqdm

import matplotlib

from matplotlib.font_manager import FontProperties
from matplotlib.ticker import FixedLocator, MaxNLocator
import cProfile
profile = cProfile.Profile()
import pstats

font0 = FontProperties()
font = font0.copy()
font.set_size(24)
font.set_family('serif')
labelfont=font0.copy()
labelfont.set_size(20)
labelfont.set_weight('bold')
legfont=font0.copy()
legfont.set_size(18)
legfont.set_weight('bold')


def set_size(w,h, ax=None):
    """ Helper function to set figure size.
        Input:
            w, h: width, height in inches """
    if not ax: ax=plt.gca()
    l = ax.figure.subplotpars.left
    r = ax.figure.subplotpars.right
    t = ax.figure.subplotpars.top
    b = ax.figure.subplotpars.bottom
    figw = float(w)/(r-l)
    figh = float(h)/(t-b)
    ax.figure.set_size_inches(figw, figh)

# %% [markdown]
# ####  Outline
#
# - Generating standard model shower
# - Generating dark photon shower
# - Plotting acceptance
# - Plotting individual processes
# - Generating novel shower samples
# - Analyzing accept-reject method in PETITE

# %% [markdown]
# ## Shower production with PETITE
#
# The primary purpose of PETITE is to produce realistic electromagnetic showers with a lightweight, reasonably fast, python-native code base. We illustrate its performance below.
#
# We will shoot a 10 GeV particle incident on either lead or graphite. Particles are specified by their PDG codes (see e.g. https://pdg.lbl.gov/2007/reviews/montecarlorpp.pdf). Units in PETITE are GeV, meters, and radians.
#
# * ${\rm PDG}(e^\pm)=\pm11$
# * ${\rm PDG}(\gamma)~~=+22$

# %%
E0 = 10. # energy of incident particle in GeV

# Define incident electron
px, py, pz = 0, 0, np.sqrt(E0**2 - 0.000511**2)

# dictionary with particle properties
# The crucial keys are 'PID' and 'ID', others are for efficient bookkeeping
particle_dict = {'PID':11, 'ID':0, 'generation_number':0, 'generation_process':'Input'}
p0 = Particle([E0, px, py, pz], [0,0,0], particle_dict)

# %%
# Shower(directory, material, minimum_energy)
sGraphite = Shower(PETITE_home_dir+dictionary_dir, "graphite", 0.010)
sLead = Shower(PETITE_home_dir+dictionary_dir, "lead", 0.010)

# Generate standard shower for graphite and lead, let's turn on verbosity to see what's going on
standard_shower_graphite = sGraphite.generate_shower(p0, VB=True)
standard_shower_lead = sLead.generate_shower(p0, VB=True)
# Out:
# Starting shower, initial particle with ID Info
# {'PID': 11, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.000511, 'stability': 'stable'}
# Initial four-momenta:
# [10.          0.          0.          9.99999999]
# Starting shower, initial particle with ID Info
# {'PID': 11, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.000511, 'stability': 'stable'}
# Initial four-momenta:
# [10.          0.          0.          9.99999999]

# %% [markdown]
# The shower is now generated. The object standard_shower_graphite is a list of particles generated throughout the shower. We can look at some of their properties.

# %%
# Let's look at different particles in the shower and their properties.
print('Total number of particles: ', len(standard_shower_graphite))

photons = [p for p in standard_shower_graphite if p.get_pid() == 22]
electrons = [p for p in standard_shower_graphite if p.get_pid() == 11]
positrons = [p for p in standard_shower_graphite if p.get_pid() == -11]
print('Number of (photons, electrons, positrons): ', len(photons), len(electrons), len(positrons))

# Let's look at the energy and angle spectra of all particles.
# Let's make these plots in log-log scale, all particles go in the same plot, energy goes in the left panel, while angle goes in the right panel.
bins_energy = np.logspace(-3, 4, 20)
bins_angle = np.logspace(-3, 0, 20) # radians
plt.figure(figsize=(12, 3))
plt.subplot(121)
plt.hist([p.get_p0()[0] for p in photons], bins=bins_energy, histtype='step', label='photons')
plt.hist([p.get_p0()[0] for p in electrons], bins=bins_energy, histtype='step', label='electrons')
plt.hist([p.get_p0()[0] for p in positrons], bins=bins_energy, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy (MeV)')
plt.ylabel('Number of particles')
plt.legend()
plt.subplot(122)
plt.hist([p.get_angle_to_z_0() for p in photons], bins=bins_angle, histtype='step', label='photons')
plt.hist([p.get_angle_to_z_0() for p in electrons], bins=bins_angle, histtype='step', label='electrons')
plt.hist([p.get_angle_to_z_0() for p in positrons], bins=bins_angle, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Angle to z-axis at production (rad)')
plt.ylabel('Number of particles')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Total number of particles:  695
# Number of (photons, electrons, positrons):  165 325 205

# %%
#Let's repeat the above but looking at the shower through lead instead of graphite:

print('Total number of particles: ', len(standard_shower_lead))
photons = [p for p in standard_shower_lead if p.get_pid() == 22]
electrons = [p for p in standard_shower_lead if p.get_pid() == 11]
positrons = [p for p in standard_shower_lead if p.get_pid() == -11]
print('Number of (photons, electrons, positrons): ', len(photons), len(electrons), len(positrons))
# Let's look at the energy and angle spectra of all particles.
# Let's make these plots in log-log scale, all particles go in the same plot, energy goes in the left panel, while angle goes in the right panel.
bins_energy = np.logspace(-3, 4, 20)
bins_angle = np.logspace(-3, 0, 20) # radians
plt.figure(figsize=(12, 3))
plt.subplot(121)
plt.hist([p.get_p0()[0] for p in photons], bins=bins_energy, histtype='step', label='photons')
plt.hist([p.get_p0()[0] for p in electrons], bins=bins_energy, histtype='step', label='electrons')
plt.hist([p.get_p0()[0] for p in positrons], bins=bins_energy, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy (MeV)')
plt.ylabel('Number of particles')
plt.legend()
plt.subplot(122)
plt.hist([p.get_angle_to_z_0() for p in photons], bins=bins_angle, histtype='step', label='photons')
plt.hist([p.get_angle_to_z_0() for p in electrons], bins=bins_angle, histtype='step', label='electrons')
plt.hist([p.get_angle_to_z_0() for p in positrons], bins=bins_angle, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Angle to z-axis at production (rad)')
plt.ylabel('Number of particles')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Total number of particles:  1496
# Number of (photons, electrons, positrons):  297 655 544

# %%
# We can also see the shower display for both graphite and lead
event_display(standard_shower_graphite)
event_display(standard_shower_lead)

# %% [markdown]
# Pretty neat, no? Notice the difference in the z-range, which is just a consequence of the smaller mean free path in lead.

# %% [markdown]
# ####  We looked at two shower objects, one with a graphite target and one with lead. Both track down to minimum energies of 10 MeV
#
# The minimum energy in the shower dictates the run-time. As one attempts to simulate lower-threshold IR physics, the computational cost increases exponentially. The number of low energy particles proliferates and one encounters many compton scatters.  10 MeV allows for reasonable simulation speed.
#
# Pre-loaded materials are lead and graphite, but other materials can be included straightforwardly running other scripts in the PETITE utilities folder

# %% [markdown]
# ## Accept/reject in PETITE
# PETITE usese VEGAS intergrator objects pre-trained on a grid of incident particle energies. During a shower the nearest energy with "good coverage" is used to draw samples, and accept reject is performed with the diffential cross section at the true physical energy.
#
# As an illustration we set an incident electron energy at $E_{e} = 1.0 ~{\rm GeV}$, and sample from several integrators trained at nearby energies for the bremsstrahlung process $e Z \rightarrow e Z \gamma$.

# %%
number_of_samples = 10000
energy_in = 1.0

xs0 = []
trials0 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=45, process='Brem', VB=True)
    xs0.append(s0[0])
    trials0.append(s0[-1])

xs1 = []
trials1 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=48, process='Brem', VB=True)
    xs1.append(s0[0])
    trials1.append(s0[-1])

xs2 = []
trials2 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=51, process='Brem', VB=True)
    xs2.append(s0[0])
    trials2.append(s0[-1])

xs3 = []
trials3 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, process='Brem', LU_Key=-1, VB=True)
    xs3.append(s0[0])
    trials3.append(s0[-1])
# Out:
#   0%|          | 0/10000 [00:00<?, ?it/s]
# 100%|██████████| 10000/10000 [00:09<00:00, 1091.83it/s]
# 100%|██████████| 10000/10000 [00:17<00:00, 558.41it/s]
# 100%|██████████| 10000/10000 [00:04<00:00, 2067.73it/s]
# 100%|██████████| 10000/10000 [00:25<00:00, 385.67it/s]

# %% [markdown]
# ### Compare efficiency of sampling for different nearby energies

# %%
bin_space = np.linspace(0, 180, 181)
plt.hist(trials0, bins=bin_space, histtype='step', lw=1, label='LU=45')
plt.hist(trials1, bins=bin_space, histtype='step', lw=1, label='LU=48')
plt.hist(trials2, bins=bin_space, histtype='step', lw=1, label='LU=51')
plt.hist(trials3, bins=bin_space, histtype='step', lw=1, label='LU=-1')
plt.gca().set_xlabel(r"$N_{\rm draw}$")
plt.gca().set_ylabel(r"$\mathrm{Occurrence}$")
plt.gca().set_yscale('log')
# show labels
plt.legend()
# print number of trials
print("Number of trials: ", len(trials0), len(trials1), len(trials2), len(trials3))
# Out:
# Number of trials:  10000 10000 10000 10000

# %% [markdown]
# ### Check distributions to see if they are insensitive to choice of integrator object

# %%
plt.hist(xs0, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.hist(xs1, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.hist(xs2, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.hist(xs3, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.gca().set_xlabel(r"$x_1\ (E_{\gamma}\ \rm{proxy})$")
plt.gca().set_ylabel(r"$\mathrm{Occurrence}$")
plt.gca().set_yscale('log')

# %% [markdown]
# ## Use of rotated coordinates

# %% [markdown]
# PETITE uses small angle variables (see e.g. sections 92-94 of Landau and Lifshitz Vol 4). However low-momentum transfers occur along a correlated "ridge" in these variables. To improve performance we have rotated angles.
#
# We illustrate the difference in performance, and benchmark total cross sections computed using the VEGAS integrators below.

# %%
xsec_dicts = pk.load(open(PETITE_home_dir+dictionary_dir+"sm_xsec.pkl", "rb"))

# %% [markdown]
# ### Pair production
#
# Cross sections are material dependent due to $Z^2$ scaling, but also due to atomic form factors (see e.g.\ Tsai Rev. Mod. Phys. (1974).

# %%
plt.plot(np.transpose(xsec_dicts['PairProd']['graphite'])[0], np.transpose(xsec_dicts['PairProd']['graphite'])[1]/6**2, color='dodgerblue', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts['PairProd']['lead'])[0], np.transpose(xsec_dicts['PairProd']['lead'])[1]/82**2, color='coral', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{\gamma}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma_{\rm pair\ prod.}/Z^2\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %% [markdown]
# ### Bremsstrahlung

# %%
plt.plot(np.transpose(xsec_dicts['Brem']['graphite'])[0], np.transpose(xsec_dicts['Brem']['graphite'])[1]/6**2, color='dodgerblue', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts['Brem']['lead'])[0], np.transpose(xsec_dicts['Brem']['lead'])[1]/82**2, color='coral', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma_{\rm brem.}/Z^2\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
plt.plot(np.transpose(xsec_dicts['Bhabha']['graphite'])[0], np.transpose(xsec_dicts['Bhabha']['graphite'])[1], color='dodgerblue', ls='-.', label=r"$\mathrm{Bhabha}$")
plt.plot(np.transpose(xsec_dicts['Moller']['graphite'])[0], np.transpose(xsec_dicts['Moller']['graphite'])[1], color='coral', ls='-.', label=r"$\mathrm{Moller}$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
plt.plot(np.transpose(xsec_dicts['Brem']['graphite'])[0], np.transpose(xsec_dicts['Brem']['graphite'])[1], color='dodgerblue', ls='-', label=r"$\mathrm{Brem.}$")
plt.plot(np.transpose(xsec_dicts['Moller']['graphite'])[0], np.transpose(xsec_dicts['Moller']['graphite'])[1]*6, color='coral', ls='-', label=r"$\mathrm{Moller}\times 6$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %% [markdown]
# ## Ensemble shower production with PETITE
#
# Expanding on the above, we can produce many showers produced by the same incident particle and analyze statistics of shower ensembles. The flexibility and speed of PETITE is a priority in this context, and so we first explore the timing of shower generation.

# %% [markdown]
# Check shower timing

# %%
def slowShower():
    s0 = sGraphite.generate_shower(p0, VB=True)
    return

# %% [markdown]
# We use the package cProfile to return useful information on the runtime. This is helpful if one would like to change $E_{\rm min}$ which can slow down the code. The output below is helpful in diagnosing bottlenecks etc.

# %%
profileSS = cProfile.Profile()
profileSS.runcall(slowShower)
psSS = pstats.Stats(profileSS)
psSS.print_stats()
# Out:
# Starting shower, initial particle with ID Info
# {'PID': 11, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.000511, 'stability': 'stable'}
# Initial four-momenta:
# [10.          0.          0.          9.99999999]
#          1684734 function calls (1670921 primitive calls) in 2.017 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         4    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#      4345    0.001    0.000    0.001    0.000 {method 'bit_length' of 'int' objects}
#     41525    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#      1460    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#     10569    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#      4197    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       511    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       707    0.001    0.000    0.001    0.000 {built-in method builtins.all}
#      8032    0.004    0.000    0.004    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        46    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#     26129    0.004    0.000    0.004    0.000 {built-in method builtins.isinstance}
#     90838    0.014    0.000    0.014    0.000 {built-in method builtins.issubclass}
#     98733    0.012    0.000    0.012    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#      2040    0.013    0.000    0.013    0.000 {built-in method builtins.round}
#         8    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#      4345    0.001    0.000    0.001    0.000 {built-in method math.cos}
#      4345    0.002    0.000    0.002    0.000 {built-in method math.log}
#      4345    0.001    0.000    0.001    0.000 {built-in method math.sin}
#      4345    0.001    0.000    0.001    0.000 {built-in method math.sqrt}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#     13035    0.002    0.000    0.002    0.000 {method 'random' of '_random.Random' objects}
#      8643    0.001    0.000    0.001    0.000 {method 'getrandbits' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x909780}
#         1    0.000    0.000    2.017    2.017 /tmp/ipykernel_1188011/143096223.py:1(slowShower)
#      1020    0.004    0.000    0.028    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:29(__init__)
#      1020    0.004    0.000    0.005    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:74(set_ids)
#     21597    0.003    0.000    0.003    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:83(get_ids)
#      1020    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:99(set_mass)
#      1020    0.004    0.000    0.017    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:101(set_p0)
#      2599    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:111(get_p0)
#      9700    0.003    0.000    0.003    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:113(set_pf)
#     26084    0.004    0.000    0.004    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:115(get_pf)
#      4345    0.031    0.000    0.069    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:122(lose_energy)
#      1020    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:132(set_r0)
#       872    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:134(get_r0)
#      5532    0.001    0.000    0.001    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:136(set_rf)
#      6070    0.001    0.000    0.001    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:138(get_rf)
#      1726    0.001    0.000    0.001    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:141(set_ended)
#    265923    0.022    0.000    0.022    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:147(get_ended)
#       510    0.010    0.000    0.010    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/particle.py:153(rotation_matrix)
#       315    0.008    0.000    0.010    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/kinematics.py:11(e_to_egamma_fourvecs)
#       102    0.002    0.000    0.003    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/kinematics.py:72(gamma_to_epem_fourvecs)
#        65    0.001    0.000    0.002    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/kinematics.py:107(compton_fourvecs)
#        17    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/kinematics.py:137(ee_to_ee_fourvecs)
#        11    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/kinematics.py:204(annihilation_fourvecs)
#     33676    0.007    0.000    0.007    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/all_processes.py:63(aa)
#     33676    0.033    0.000    0.040    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/all_processes.py:70(g2_elastic)
#     35458    0.435    0.000    0.581    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/all_processes.py:105(dsigma_brem_dimensionless)
#        21    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/all_processes.py:360(dsigma_annihilation_dCT)
#      5010    0.055    0.000    0.076    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/all_processes.py:405(dsigma_pairprod_dimensionless)
#        67    0.002    0.000    0.002    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/all_processes.py:452(dsigma_compton_dCT)
#       158    0.001    0.000    0.001    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/all_processes.py:503(dsigma_moller_dCT)
#       102    0.001    0.000    0.001    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/all_processes.py:545(dsigma_bhabha_dCT)
#      4345    0.018    0.000    0.018    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/moliere.py:150(get_chic_squared_alt)
#      4345    0.020    0.000    0.020    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/moliere.py:165(get_chia_squared_alt)
#      4345    0.032    0.000    0.101    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/moliere.py:215(generate_moliere_angle_simplified_alt)
#      4345    0.075    0.000    0.089    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/moliere.py:237(get_rotation_matrix)
#      4345    0.081    0.000    0.355    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/moliere.py:307(get_scattered_momentum)
#     12707    0.016    0.000    0.292    0.000 /home/pedro/.local/lib/python3.8/site-packages/scipy/interpolate/_polyint.py:58(__call__)
#     12707    0.012    0.000    0.105    0.000 /home/pedro/.local/lib/python3.8/site-packages/scipy/interpolate/_polyint.py:89(_prepare_x)
#     12707    0.008    0.000    0.016    0.000 /home/pedro/.local/lib/python3.8/site-packages/scipy/interpolate/_polyint.py:95(_finish_y)
#     12707    0.004    0.000    0.006    0.000 /home/pedro/.local/lib/python3.8/site-packages/scipy/sparse/_base.py:1301(isspmatrix)
#     12707    0.039    0.000    0.089    0.000 /home/pedro/.local/lib/python3.8/site-packages/scipy/_lib/_util.py:206(_asarray_validated)
#     12707    0.009    0.000    0.082    0.000 /home/pedro/.local/lib/python3.8/site-packages/scipy/interpolate/_interpolate.py:672(_call_linear_np)
#     12707    0.024    0.000    0.155    0.000 /home/pedro/.local/lib/python3.8/site-packages/scipy/interpolate/_interpolate.py:745(_evaluate)
#     12707    0.045    0.000    0.045    0.000 /home/pedro/.local/lib/python3.8/site-packages/scipy/interpolate/_interpolate.py:760(_check_bounds)
#       538    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/shower.py:146(get_material_properties)
#      4678    0.022    0.000    0.277    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/shower.py:226(get_mfp)
#       510    0.006    0.000    0.006    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/shower.py:265(<listcomp>)
#       510    0.170    0.000    0.906    0.002 /home/pedro/.local/lib/python3.8/site-packages/PETITE/shower.py:247(draw_sample)
#       696    0.018    0.000    0.996    0.001 /home/pedro/.local/lib/python3.8/site-packages/PETITE/shower.py:322(sample_scattering)
#       705    0.057    0.000    0.846    0.001 /home/pedro/.local/lib/python3.8/site-packages/PETITE/shower.py:365(propagate_particle)
#         2    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/shower.py:518(<listcomp>)
#       705    0.050    0.000    0.071    0.000 /home/pedro/.local/lib/python3.8/site-packages/PETITE/shower.py:538(<listcomp>)
#         1    0.019    0.019    2.017    2.017 /home/pedro/.local/lib/python3.8/site-packages/PETITE/shower.py:485(generate_shower)
#     12707    0.003    0.000    0.005    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/ma/core.py:6450(isMaskedArray)
#     40816    0.024    0.000    0.024    0.000 {method 'random' of 'numpy.random.mtrand.RandomState' objects}
#       696    0.028    0.000    0.032    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#      9533    0.035    0.000    0.035    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#     18957    0.011    0.000    0.124    0.000 <__array_function__ internals>:177(norm)
#     12707    0.002    0.000    0.002    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:1453(_interp_dispatcher)
#     12707    0.016    0.000    0.054    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:1457(interp)
#     12707    0.008    0.000    0.073    0.000 <__array_function__ internals>:177(interp)
#     12707    0.007    0.000    0.023    0.000 <__array_function__ internals>:177(iscomplexobj)
#     18957    0.005    0.000    0.007    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py:117(isComplexType)
#     18957    0.003    0.000    0.003    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py:2338(_norm_dispatcher)
#     18957    0.050    0.000    0.097    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/linalg/linalg.py:2342(norm)
#     12707    0.002    0.000    0.002    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/lib/type_check.py:206(_is_type_dispatcher)
#     12707    0.007    0.000    0.008    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/lib/type_check.py:303(iscomplexobj)
#      1392    0.002    0.000    0.002    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/getlimits.py:476(__new__)
#         2    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:33(seterr)
#         2    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:132(geterr)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:426(__init__)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:430(__enter__)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/_ufunc_config.py:435(__exit__)
#      4345    0.003    0.000    0.014    0.000 <__array_function__ internals>:177(transpose)
#       510    0.001    0.000    0.004    0.000 <__array_function__ internals>:177(argmin)
#     41326    0.021    0.000    0.065    0.000 <__array_function__ internals>:177(shape)
#       704    0.001    0.000    0.011    0.000 <__array_function__ internals>:177(sum)
#      1020    0.001    0.000    0.010    0.000 <__array_function__ internals>:177(all)
#      1402    0.001    0.000    0.018    0.000 <__array_function__ internals>:177(amax)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(amin)
#      1067    0.001    0.000    0.012    0.000 <__array_function__ internals>:177(prod)
#      1067    0.001    0.000    0.016    0.000 <__array_function__ internals>:177(product)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:72(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:64(_make_options_dict)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:411(<lambda>)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:403(_get_formatdict)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:452(_get_format_function)
#         1    0.000    0.000    0.001    0.001 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:506(wrapper)
#         1    0.000    0.000    0.001    0.001 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:523(_array2string)
#         1    0.000    0.000    0.001    0.001 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:561(array2string)
#         4    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:739(_extendLine)
#         4    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:753(_extendLine_pretty)
#       5/1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:789(recurser)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:780(_formatArray)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:898(_none_or_positive_arg)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:907(__init__)
#         5    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:984(<genexpr>)
#         5    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:989(<genexpr>)
#         5    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:993(<genexpr>)
#         5    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:994(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:934(fillFormat)
#         4    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:1018(__call__)
#         1    0.000    0.000    0.001    0.001 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/arrayprint.py:1571(_array_str_implementation)
#      1530    0.001    0.000    0.007    0.000 <__array_function__ internals>:177(concatenate)
#      1020    0.001    0.000    0.006    0.000 <__array_function__ internals>:177(dot)
#      1020    0.001    0.000    0.004    0.000 <__array_function__ internals>:177(copyto)
#     26806    0.013    0.000    0.020    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/numerictypes.py:282(issubclass_)
#     13403    0.013    0.000    0.034    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/numerictypes.py:356(issubdtype)
#       510    0.001    0.000    0.003    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/numeric.py:150(ones)
#       510    0.001    0.000    0.004    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/numeric.py:290(full)
#      4855    0.003    0.000    0.008    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:51(_wrapfunc)
#      4194    0.003    0.000    0.003    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:70(<dictcomp>)
#      4194    0.011    0.000    0.037    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:69(_wrapreduction)
#      4345    0.001    0.000    0.001    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:597(_transpose_dispatcher)
#      4345    0.002    0.000    0.008    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:601(transpose)
#       510    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:1245(_argmin_dispatcher)
#       510    0.001    0.000    0.003    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:1249(argmin)
#     41326    0.005    0.000    0.005    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:1987(_shape_dispatcher)
#     41326    0.011    0.000    0.011    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:1991(shape)
#       704    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2183(_sum_dispatcher)
#       704    0.001    0.000    0.010    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2188(sum)
#      1020    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2427(_all_dispatcher)
#      1020    0.001    0.000    0.008    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2432(all)
#      1402    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2698(_amax_dispatcher)
#      1402    0.002    0.000    0.015    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2703(amax)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2824(_amin_dispatcher)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2829(amin)
#      2134    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2950(_prod_dispatcher)
#      1067    0.001    0.000    0.010    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:2955(prod)
#      1067    0.001    0.000    0.013    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3766(product)
#         2    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#       510    0.001    0.000    0.001    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     18957    0.019    0.000    0.019    0.000 {method 'dot' of 'numpy.ndarray' objects}
#     31664    0.010    0.000    0.010    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     12707    0.008    0.000    0.008    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      4345    0.002    0.000    0.002    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     64071    0.081    0.000    0.081    0.000 {built-in method numpy.array}
#     57079    0.022    0.000    0.022    0.000 {built-in method numpy.asarray}
#      4345    0.003    0.000    0.003    0.000 {built-in method numpy.zeros}
#      1020    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
# 99383/85609    0.076    0.000    0.290    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     12707    0.014    0.000    0.014    0.000 {built-in method numpy.core._multiarray_umath.interp}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         1    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.generic' objects}
#      4194    0.021    0.000    0.021    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      1530    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/multiarray.py:152(concatenate)
#      1020    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/multiarray.py:740(dot)
#      1020    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/numpy/core/multiarray.py:1079(copyto)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/ipykernel/iostream.py:97(_event_pipe)
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/ipykernel/iostream.py:209(schedule)
#         8    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/ipykernel/iostream.py:436(_is_master_process)
#         8    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/ipykernel/iostream.py:455(_schedule_flush)
#         8    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/ipykernel/iostream.py:525(write)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /home/pedro/.local/lib/python3.8/site-packages/zmq/sugar/socket.py:540(send)
#      4345    0.005    0.000    0.007    0.000 /usr/lib/python3.8/random.py:250(_randbelow_with_getrandbits)
#      4345    0.004    0.000    0.012    0.000 /usr/lib/python3.8/random.py:285(choice)
#      4345    0.002    0.000    0.003    0.000 /usr/lib/python3.8/random.py:415(uniform)
#      8690    0.012    0.000    0.019    0.000 /usr/lib/python3.8/random.py:616(gauss)
#      35/1    0.000    0.000    0.000    0.000 /usr/lib/python3.8/copy.py:128(deepcopy)
#        26    0.000    0.000    0.000    0.000 /usr/lib/python3.8/copy.py:182(_deepcopy_atomic)
#       2/1    0.000    0.000    0.000    0.000 /usr/lib/python3.8/copy.py:226(_deepcopy_dict)
#         6    0.000    0.000    0.000    0.000 /usr/lib/python3.8/copy.py:242(_keep_alive)
#         2    0.000    0.000    0.000    0.000 /usr/lib/python3.8/copy.py:263(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.8/copy.py:258(_reconstruct)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.8/threading.py:513(is_set)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.8/threading.py:1017(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.8/threading.py:1071(is_alive)
#         1    0.000    0.000    0.000    0.000 /usr/lib/python3.8/copyreg.py:90(__newobj__)

# %% [markdown]
# ## Tests and validations
#
# Generate some ensembles of brem./pair production samples, with 10 GeV particles injected and check basic properties of distributions

# %%
particle_dict_gamma = {'PID':22, 'ID':0, 'generation_number':0, 'generation_process':'Input'}
p0G = Particle([E0, 0, 0, E0], [0,0,0], particle_dict_gamma)

# %%
nSamp = 20000 # make this larger if you want more precision (it is slower though)...
s0 = np.array([sGraphite.sample_scattering(p0, process="Brem", VB=True) for i in tqdm(range(nSamp))])
s0G = np.array([sGraphite.sample_scattering(p0G, process="PairProd", VB=True) for i in tqdm(range(nSamp))])
# Out:
# 100%|██████████| 20000/20000 [00:15<00:00, 1266.49it/s]
# 100%|██████████| 20000/20000 [00:11<00:00, 1772.12it/s]

# %%
Es = np.array([s[1].get_p0()[0] for s in s0])
EsE = np.array([s[0].get_p0()[0] for s in s0])

EsG = np.array([s[1].get_p0()[0] for s in s0G])
EsGP = np.array([s[0].get_p0()[0] for s in s0G])

# %% [markdown]
# ### Photon and electron distribution from first scatter
#
# We expect a flat photon distribution in log-space

# %%
b0 = np.logspace(-3, 1, 41)

dens = False
plt.hist(Es, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\mathrm{SM,\ Ryan\ Approach}$")
plt.hist(EsE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--')

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_\gamma\ \mathrm{or}\ E_{e^-}\ [\mathrm{GeV}]$", fontsize=18)
plt.gca().set_ylabel(r"$\mathrm{particles/bin}$", fontsize=18)
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ### Look at angular distributions of outgoing particles from bremsstrahlung/pair production in terms of their $p_T/p_z$

# %%
pTpz = np.array([(s[1].get_p0()[3]/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0])
pTpzE = np.array([(s[0].get_p0()[3]/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0])

pTpzG = np.array([(s[1].get_p0()[3]/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0G])
pTpzGP = np.array([(s[0].get_p0()[3]/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0G])

# %%
pT = np.array([(1/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0])
pTE = np.array([(1/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0])

pTG = np.array([(1/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0G])
pTGP = np.array([(1/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0G])

# %%
b0 = np.logspace(-10, 2, 41)

dens = True
plt.hist(pTpz, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\gamma,\ \rm{brem.}$")
plt.hist(pTpzE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--', label=r"$e^{-},\ \rm{brem.}$")

plt.hist(pTpzG, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='-', label=r"$e^{-},\ \rm{pair\ prod.}$")
plt.hist(pTpzGP, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='--', label=r"$e^{+},\ \rm{pair\ prod.}$")

plt.gca().legend(loc='best', fontsize=14, framealpha=1.0)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$p_T/p_z$", fontsize=18)
plt.gca().set_ylabel(r"$dN/d(p_T/p_z)$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %%
b0 = np.logspace(-10, 2, 41)

dens = True
plt.hist(pT, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\gamma,\ \rm{brem.}$")
plt.hist(pTE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--', label=r"$e^{-},\ \rm{brem.}$")

plt.hist(pTG, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='-', label=r"$e^{-},\ \rm{pair\ prod.}$")
plt.hist(pTGP, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='--', label=r"$e^{+},\ \rm{pair\ prod.}$")

plt.gca().legend(loc='best', fontsize=14, framealpha=1.0)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$p_T\ [\mathrm{GeV}]$", fontsize=18)
plt.gca().set_ylabel(r"$dN/d(p_T)$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ## Outgoing electron/positron energies coming from pair production: should be identical

# %%
b0 = np.logspace(-4, 2, 41)

dens=False 

plt.hist(EsG, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-')
plt.hist(EsGP, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--')

#plt.gca().legend(loc=2, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_{e^\pm}\ [\mathrm{GeV}]$", fontsize=18)
plt.gca().set_ylabel(r"$\mathrm{photons/bin}$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ### Event-by-event ratio of $E_{e^-}/E_{e^+}$: should be symmetric about 1.

# %%
b0 = np.logspace(-4, 4, 61)

plt.hist(EsG/EsGP, bins=b0, histtype='step', lw=3, color='C6', density=False, ls='-', label=r"$\mathrm{SM,\ Ryan\ Approach}$")

#plt.gca().legend(loc=1, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_{e^-}/E_{e^+}$", fontsize=18)
plt.gca().set_ylabel(r"$\mathrm{simulations}$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]
plt.gca().axvline(1.0, color='k', lw=1, ls='--')

set_size(5.0, 3.0)

# %% [markdown]
# ### Asymmetry of the distribution.
#
# A basic test is distributions should be symmetric under  $e^+\leftrightarrow e^-$. We expect deviations due to statistical flucutations, on the order of $1/\sqrt{N}$ where $N$ is the size of the sample.

# %%
print("Asymmetry", (len(np.where(EsG > E0/2)[0]) - len(np.where(EsG < E0/2)[0]))/len(EsG) ) 
print("Statistical Error:" , 1/np.sqrt(len(EsG)) )
# Out:
# Asymmetry -0.007
# Statistical Error: 0.007071067811865475
