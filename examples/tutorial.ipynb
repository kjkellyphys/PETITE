# %% [markdown]
# # PETITE Tutorial
# Authors: Nikita Blinov (York U.), Patrick J. Fox (Fermilab), Kevin J. Kelly (Texas A&M), Pedro A. N. Machado (Fermilab), and Ryan Plestid (Caltech)
#
# PETITE is a simple, lightweight, toy Monte Carlo that generates realistic electromagnetic showers, with or without new physics.
# Currently, dark photons with pure vector couplins are incorporated in PETITE.
#
# PETITE includes explicit simulation of (we denote nuclei by their electric charge $Z$)
#
# * Bremsstrahlung  $e^\pm Z \rightarrow e^\pm \gamma Z$.
# * Pair production $\gamma Z \rightarrow e^+ e^- Z$.
# * Compton scattering $\gamma e^- \rightarrow  \gamma e^-$
# * Pair-annihilation $e^+ e^- \rightarrow \gamma\gamma$
# * Moller Scattering $e^- e^- \rightarrow e^- e^-$
# * Bhabha Scattering $e^+ e^- \rightarrow e^+ e^-$
#
# and implicit simulation of
#
# * Multiple Coulomb scattering
# * Energy loss by ionization
#
# ${\bf Dependencies}$: numpy, vegas, pickle, cProfile, tqdm, scipy
#
# ${\bf Version~ requirements}$: numpy 1.24  ,  python3.xx with xx$\geq$9.
#
# ${\bf Directory~structure}$: This notebook assumes that within a PETITE home directory there is folder containing dictionaries, and that within that folder the following files exist
#
# * $\verb|<PETITE_home_dir>|$/$\verb|<dictionary_dir>|$/sm_xsec.pkl
# * $\verb|<PETITE_home_dir>|$/$\verb|<dictionary_dir>|$/sm_maps.pkl
#
# You can check versions with the code below and adjust if necessary.
#
# In this tutorial you will learn how to
# 1. Initialize PETITE
# 2. Generate a standard electromagnetic shower
# 3. Generate a shower with a dark photon
# 4. Analyze the accept/reject method used by PETITE, based on precomputed shower samples
# 5. Understand how to generate novel shower samples.

# %%
# Force reload (if changes have been made to the module)
# %load_ext autoreload
# %autoreload 2

# Initialization of the tutorial
from platform import python_version
print("Python version: ", python_version())

import numpy
print("Numpy version: ", numpy.__version__)

import os
current_path = os.getcwd()
PETITE_home_dir= current_path.split('examples')[0]

print("PETITE home directory:", PETITE_home_dir)
# folder where VEGAS dictionaries are stored
# dictionary_dir = "data/VEGAS_dictionaries/"
dictionary_dir = "data_test/data/"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Python version:  3.12.4
# Numpy version:  1.26.4
# PETITE home directory: /Users/kjkelly/Library/CloudStorage/Dropbox/GitHub/PETITE/

# %% [markdown]
# ### Load in dependencies and set font styles

# %%
from PETITE.shower import *
import pickle as pk
from matplotlib import pyplot as plt
from tqdm import tqdm
#from tqdm.notebook import tqdm

import matplotlib

from matplotlib.font_manager import FontProperties
from matplotlib.ticker import FixedLocator, MaxNLocator
import cProfile
profile = cProfile.Profile()
import pstats

font0 = FontProperties()
font = font0.copy()
font.set_size(24)
font.set_family('serif')
labelfont=font0.copy()
labelfont.set_size(20)
labelfont.set_weight('bold')
legfont=font0.copy()
legfont.set_size(18)
legfont.set_weight('bold')


def set_size(w,h, ax=None):
    """ Helper function to set figure size.
        Input:
            w, h: width, height in inches """
    if not ax: ax=plt.gca()
    l = ax.figure.subplotpars.left
    r = ax.figure.subplotpars.right
    t = ax.figure.subplotpars.top
    b = ax.figure.subplotpars.bottom
    figw = float(w)/(r-l)
    figh = float(h)/(t-b)
    ax.figure.set_size_inches(figw, figh)

# %% [markdown]
# ####  Outline
#
# - Generating standard model shower
# - Generating dark photon shower
# - Plotting acceptance
# - Plotting individual processes
# - Generating novel shower samples
# - Analyzing accept-reject method in PETITE

# %% [markdown]
# ## Shower production with PETITE
#
# The primary purpose of PETITE is to produce realistic electromagnetic showers with a lightweight, reasonably fast, python-native code base. We illustrate its performance below.
#
# We will shoot a 10 GeV particle incident on either lead or graphite. Particles are specified by their PDG codes (see e.g. https://pdg.lbl.gov/2007/reviews/montecarlorpp.pdf). Units in PETITE are GeV, meters, and radians.
#
# * ${\rm PDG}(e^\pm)=\pm11$
# * ${\rm PDG}(\gamma)~~=+22$

# %%
E0 = 10. # energy of incident particle in GeV

# Define incident electron
#px, py, pz = 0, 0, np.sqrt(E0**2 - 0.000511**2)
px, py, pz = 0, 0, E0

# dictionary with particle properties
# The crucial keys are 'PID' and 'ID', others are for efficient bookkeeping
particle_dict = {'PID':22, 'ID':0, 'generation_number':0, 'generation_process':'Input'}
p0 = Particle([E0, px, py, pz], [0,0,0], particle_dict)

# %%
# Shower(directory, material, minimum_energy)
sGraphite = Shower(PETITE_home_dir+dictionary_dir, "graphite", 0.010)
sLead = Shower(PETITE_home_dir+dictionary_dir, "lead", 0.010)

# %%
# Generate standard shower for graphite and lead, let's turn on verbosity to see what's going on
standard_shower_graphite = sGraphite.generate_shower(p0, VB=True)
standard_shower_lead = sLead.generate_shower(p0, VB=True)
# Out:
# Starting shower, initial particle with ID Info
# {'PID': 22, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.0, 'stability': 'stable', 'production_time': 0.0, 'decay_time': 0.0, 'interaction_time': 0.0}
# Initial four-momenta:
# [10.  0.  0. 10.]
# Starting shower, initial particle with ID Info
# {'PID': 22, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.0, 'stability': 'stable', 'production_time': 0.0, 'decay_time': 0.0, 'interaction_time': 0.0}
# Initial four-momenta:
# [10.  0.  0. 10.]

# %% [markdown]
# The shower is now generated. The object standard_shower_graphite is a list of particles generated throughout the shower. We can look at some of their properties.

# %%
# Let's look at different particles in the shower and their properties.
print('Total number of particles: ', len(standard_shower_graphite))

photons = [p for p in standard_shower_graphite if p.get_pid() == 22]
electrons = [p for p in standard_shower_graphite if p.get_pid() == 11]
positrons = [p for p in standard_shower_graphite if p.get_pid() == -11]
print('Number of (photons, electrons, positrons): ', len(photons), len(electrons), len(positrons))

# Let's look at the energy and angle spectra of all particles.
# Let's make these plots in log-log scale, all particles go in the same plot, energy goes in the left panel, while angle goes in the right panel.
bins_energy = np.logspace(-3, 4, 20)
bins_angle = np.logspace(-3, 0, 20) # radians
plt.figure(figsize=(12, 3))
plt.subplot(121)
plt.hist([p.get_p0()[0] for p in photons], bins=bins_energy, histtype='step', label='photons')
plt.hist([p.get_p0()[0] for p in electrons], bins=bins_energy, histtype='step', label='electrons')
plt.hist([p.get_p0()[0] for p in positrons], bins=bins_energy, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy (MeV)')
plt.ylabel('Number of particles')
plt.legend()
plt.subplot(122)
plt.hist([p.get_angle_to_z_0() for p in photons], bins=bins_angle, histtype='step', label='photons')
plt.hist([p.get_angle_to_z_0() for p in electrons], bins=bins_angle, histtype='step', label='electrons')
plt.hist([p.get_angle_to_z_0() for p in positrons], bins=bins_angle, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Angle to z-axis at production (rad)')
plt.ylabel('Number of particles')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Total number of particles:  104
# Number of (photons, electrons, positrons):  2 44 58

# %%
#Let's repeat the above but looking at the shower through lead instead of graphite:

print('Total number of particles: ', len(standard_shower_lead))
photons = [p for p in standard_shower_lead if p.get_pid() == 22]
electrons = [p for p in standard_shower_lead if p.get_pid() == 11]
positrons = [p for p in standard_shower_lead if p.get_pid() == -11]
print('Number of (photons, electrons, positrons): ', len(photons), len(electrons), len(positrons))
# Let's look at the energy and angle spectra of all particles.
# Let's make these plots in log-log scale, all particles go in the same plot, energy goes in the left panel, while angle goes in the right panel.
bins_energy = np.logspace(-3, 4, 20)
bins_angle = np.logspace(-3, 0, 20) # radians
plt.figure(figsize=(12, 3))
plt.subplot(121)
plt.hist([p.get_p0()[0] for p in photons], bins=bins_energy, histtype='step', label='photons')
plt.hist([p.get_p0()[0] for p in electrons], bins=bins_energy, histtype='step', label='electrons')
plt.hist([p.get_p0()[0] for p in positrons], bins=bins_energy, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Energy (MeV)')
plt.ylabel('Number of particles')
plt.legend()
plt.subplot(122)
plt.hist([p.get_angle_to_z_0() for p in photons], bins=bins_angle, histtype='step', label='photons')
plt.hist([p.get_angle_to_z_0() for p in electrons], bins=bins_angle, histtype='step', label='electrons')
plt.hist([p.get_angle_to_z_0() for p in positrons], bins=bins_angle, histtype='step', label='positrons')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Angle to z-axis at production (rad)')
plt.ylabel('Number of particles')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Total number of particles:  129
# Number of (photons, electrons, positrons):  1 86 42

# %%
# We can also see the shower display for both graphite and lead
event_display(standard_shower_graphite)
event_display(standard_shower_lead)

# %% [markdown]
# Pretty neat, no? Notice the difference in the z-range, which is just a consequence of the smaller mean free path in lead.

# %% [markdown]
# ####  We looked at two shower objects, one with a graphite target and one with lead. Both track down to minimum energies of 10 MeV
#
# The minimum energy in the shower dictates the run-time. As one attempts to simulate lower-threshold IR physics, the computational cost increases exponentially. The number of low energy particles proliferates and one encounters many compton scatters.  10 MeV allows for reasonable simulation speed.
#
# Pre-loaded materials are lead and graphite, but other materials can be included straightforwardly running other scripts in the PETITE utilities folder

# %% [markdown]
# ## Accept/reject in PETITE
# PETITE usese VEGAS intergrator objects pre-trained on a grid of incident particle energies. During a shower the nearest energy with "good coverage" is used to draw samples, and accept reject is performed with the diffential cross section at the true physical energy.
#
# As an illustration we set an incident electron energy at $E_{e} = 1.0 ~{\rm GeV}$, and sample from several integrators trained at nearby energies for the bremsstrahlung process $e Z \rightarrow e Z \gamma$.

# %%
sample_list = sGraphite._loaded_samples
energies = sample_list["Brem"][0:]
energies = np.array([x[0] for x in energies])

Einc = 1.0
LU_Key = np.argmin(np.abs(energies - Einc)) + 1

print(LU_Key)
# Out:
# 27

# %%
number_of_samples = 10000
energy_in = 1.0

xs0 = []
trials0 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=25, process='Brem', VB=True)
    xs0.append(s0[0])
    trials0.append(s0[-1])

xs1 = []
trials1 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=26, process='Brem', VB=True)
    xs1.append(s0[0])
    trials1.append(s0[-1])

xs2 = []
trials2 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, LU_Key=28, process='Brem', VB=True)
    xs2.append(s0[0])
    trials2.append(s0[-1])

xs3 = []
trials3 = []
for k in tqdm(range(int(number_of_samples))):
    s0 = sGraphite.draw_sample(energy_in, process='Brem', LU_Key=-1, VB=True)
    xs3.append(s0[0])
    trials3.append(s0[-1])
# Out:
# 100%|██████████| 10000/10000 [00:01<00:00, 5713.80it/s]
# 100%|██████████| 10000/10000 [00:03<00:00, 2772.30it/s]
# 100%|██████████| 10000/10000 [00:01<00:00, 5985.61it/s]
# 100%|██████████| 10000/10000 [00:02<00:00, 3863.09it/s]

# %% [markdown]
# ### Compare efficiency of sampling for different nearby energies

# %%
bin_space = np.linspace(0, 180, 181)
plt.hist(trials0, bins=bin_space, histtype='step', lw=1, label='LU=45')
plt.hist(trials1, bins=bin_space, histtype='step', lw=1, label='LU=48')
plt.hist(trials2, bins=bin_space, histtype='step', lw=1, label='LU=51')
plt.hist(trials3, bins=bin_space, histtype='step', lw=1, label='LU=-1')
plt.gca().set_xlabel(r"$N_{\rm draw}$")
plt.gca().set_ylabel(r"$\mathrm{Occurrence}$")
plt.gca().set_yscale('log')
# show labels
plt.legend()
# print number of trials
print("Number of trials: ", len(trials0), len(trials1), len(trials2), len(trials3))
# Out:
# Number of trials:  10000 10000 10000 10000

# %% [markdown]
# ### Check distributions to see if they are insensitive to choice of integrator object

# %%
plt.hist(xs0, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.hist(xs1, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.hist(xs2, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.hist(xs3, bins=np.linspace(0, 1, 101), histtype='step', lw=1)
plt.gca().set_xlabel(r"$x_1\ (E_{\gamma}\ \rm{proxy})$")
plt.gca().set_ylabel(r"$\mathrm{Occurrence}$")
plt.gca().set_yscale('log')

# %% [markdown]
# ## Use of rotated coordinates

# %% [markdown]
# PETITE uses small angle variables (see e.g. sections 92-94 of Landau and Lifshitz Vol 4). However low-momentum transfers occur along a correlated "ridge" in these variables. To improve performance we have rotated angles.
#
# We illustrate the difference in performance, and benchmark total cross sections computed using the VEGAS integrators below.

# %%
xsec_dicts = pk.load(open(PETITE_home_dir+"data/sm_xsec.pkl", "rb"))
xsec_dicts_new = pk.load(open(PETITE_home_dir+"data_test/data/sm_xsec.pkl", "rb"))

# %% [markdown]
# ### Pair production
#
# Cross sections are material dependent due to $Z^2$ scaling, but also due to atomic form factors (see e.g.\ Tsai Rev. Mod. Phys. (1974).

# %%
plt.plot(np.transpose(xsec_dicts['PairProd']['graphite'])[0], np.transpose(xsec_dicts['PairProd']['graphite'])[1]/6**2, color='dodgerblue', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts['PairProd']['lead'])[0], np.transpose(xsec_dicts['PairProd']['lead'])[1]/82**2, color='coral', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts_new['PairProd']['graphite'])[0], 40*np.transpose(xsec_dicts_new['PairProd']['graphite'])[1], color='dodgerblue', ls='-', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts_new['PairProd']['lead'])[0], 40*np.transpose(xsec_dicts_new['PairProd']['lead'])[1], color='coral', ls='-', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{\gamma}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma_{\rm pair\ prod.}/Z^2\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %% [markdown]
# ### Bremsstrahlung

# %%
plt.plot(np.transpose(xsec_dicts['Brem']['graphite'])[0], np.transpose(xsec_dicts['Brem']['graphite'])[1]/6**2, color='dodgerblue', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts['Brem']['lead'])[0], np.transpose(xsec_dicts['Brem']['lead'])[1]/82**2, color='coral', ls='-.', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts_new['Brem']['graphite'])[0], 40*np.transpose(xsec_dicts_new['Brem']['graphite'])[1], color='dodgerblue', ls='-', label=r"$\mathrm{Rotated/dimensionless,\ graphite,\ }n_{\rm eval}=300$")
plt.plot(np.transpose(xsec_dicts_new['Brem']['lead'])[0], 40*np.transpose(xsec_dicts_new['Brem']['lead'])[1], color='coral', ls='-', label=r"$\mathrm{Rotated/dimensionless,\ lead,\ }n_{\rm eval}=300$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma_{\rm brem.}/Z^2\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
plt.plot(np.transpose(xsec_dicts['Bhabha']['graphite'])[0], np.transpose(xsec_dicts['Bhabha']['graphite'])[1], color='dodgerblue', ls='-.', label=r"$\mathrm{Bhabha}$")
plt.plot(np.transpose(xsec_dicts['Moller']['graphite'])[0], np.transpose(xsec_dicts['Moller']['graphite'])[1], color='coral', ls='-.', label=r"$\mathrm{Moller}$")

plt.plot(np.transpose(xsec_dicts_new['Bhabha']['graphite'])[0], 40*np.transpose(xsec_dicts_new['Bhabha']['graphite'])[1], color='dodgerblue', ls='-', label=r"$\mathrm{Bhabha}$")
plt.plot(np.transpose(xsec_dicts_new['Moller']['graphite'])[0], 40*np.transpose(xsec_dicts_new['Moller']['graphite'])[1], color='coral', ls='-', label=r"$\mathrm{Moller}$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
plt.plot(np.transpose(xsec_dicts['Brem']['graphite'])[0], np.transpose(xsec_dicts['Brem']['graphite'])[1], color='dodgerblue', ls='-', label=r"$\mathrm{Brem.}$")
plt.plot(np.transpose(xsec_dicts['Moller']['graphite'])[0], np.transpose(xsec_dicts['Moller']['graphite'])[1]*6, color='coral', ls='-', label=r"$\mathrm{Moller}\times 6$")

plt.plot(np.transpose(xsec_dicts_new['Brem']['graphite'])[0], np.transpose(xsec_dicts_new['Brem']['graphite'])[1], color='dodgerblue', ls='--', label=r"$\mathrm{Brem.}$")
plt.plot(np.transpose(xsec_dicts_new['Moller']['graphite'])[0], np.transpose(xsec_dicts_new['Moller']['graphite'])[1]*6, color='coral', ls='--', label=r"$\mathrm{Moller}\times 6$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
plt.plot(np.transpose(xsec_dicts_new['MuonBrem']['graphite'])[0], np.transpose(xsec_dicts_new['MuonBrem']['graphite'])[1], color='dodgerblue', ls='--', label=r"$\mathrm{Muon\ Brem.}$")
#plt.plot(np.transpose(xsec_dicts_new['MuonBrem']['lead'])[0], np.transpose(xsec_dicts_new['MuonBrem']['lead'])[1], color='coral', ls='--', label=r"$\mathrm{Moller}\times 6$")

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %%
for target in xsec_dicts_new['Brem'].keys():
    plt.plot(np.transpose(xsec_dicts_new['Brem'][target])[0], np.transpose(xsec_dicts_new['Brem'][target])[1], label=target)

for target in xsec_dicts_new['PairProd'].keys():
    plt.plot(np.transpose(xsec_dicts_new['PairProd'][target])[0], np.transpose(xsec_dicts_new['PairProd'][target])[1], ls='--', label=target)

plt.legend(loc='best')

plt.gca().set_xlabel(r"$E_{e}\ [\mathrm{GeV}]$")
plt.gca().set_ylabel(r"$\sigma\ [\mathrm{GeV^{-2}}]$")

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')

# %% [markdown]
# ## Ensemble shower production with PETITE
#
# Expanding on the above, we can produce many showers produced by the same incident particle and analyze statistics of shower ensembles. The flexibility and speed of PETITE is a priority in this context, and so we first explore the timing of shower generation.

# %% [markdown]
# Check shower timing

# %%
def slowShower():
    s0 = sGraphite.generate_shower(p0, VB=True)
    return

# %% [markdown]
# We use the package cProfile to return useful information on the runtime. This is helpful if one would like to change $E_{\rm min}$ which can slow down the code. The output below is helpful in diagnosing bottlenecks etc.

# %%
profileSS = cProfile.Profile()
profileSS.runcall(slowShower)
psSS = pstats.Stats(profileSS)
psSS.print_stats()
# Out:
# Starting shower, initial particle with ID Info
# {'PID': 11, 'ID': 0, 'parent_PID': 22, 'parent_ID': -1, 'generation_number': 0, 'generation_process': 'Input', 'weight': 1.0, 'mass': 0.000511, 'stability': 'stable', 'production_time': 0.0, 'decay_time': 0.0, 'interaction_time': 0.0}
# Initial four-momenta:
# [10.          0.          0.          9.99999999]
#          1698291 function calls (1698239 primitive calls) in 2.590 seconds
#
#    Random listing order was used
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#       713    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#      4998    0.001    0.000    0.001    0.000 {method 'bit_length' of 'int' objects}
#      1470    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#     14280    0.001    0.000    0.001    0.000 {method 'keys' of 'dict' objects}
#      5401    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#       537    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x100c732b0}
#         5    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#       702    0.001    0.000    0.001    0.000 {built-in method builtins.all}
#      8789    0.002    0.000    0.002    0.000 {built-in method builtins.getattr}
#        13    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        52    0.000    0.000    0.000    0.000 {built-in method builtins.id}
# 28830/28826    0.003    0.000    0.003    0.000 {built-in method builtins.isinstance}
#    101266    0.009    0.000    0.009    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#     64182    0.005    0.000    0.005    0.000 {built-in method builtins.len}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.001    0.000 {built-in method builtins.print}
#         3    0.000    0.000    0.017    0.006 {method 'run' of '_contextvars.Context' objects}
#         8    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#        12    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         6    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         5    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {method 'close' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         8    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#       5/4    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#        12    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         7    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:1153(_wait_for_tstate_lock)
#         8    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/enum.py:1531(__or__)
#         6    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/enum.py:1541(__and__)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/json/encoder.py:183(encode)
#        20    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/enum.py:713(__call__)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/copyreg.py:98(__newobj__)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/typing.py:1446(__subclasscheck__)
#        57    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/typing.py:2132(cast)
#         6    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/typing.py:378(inner)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/typing.py:1239(__hash__)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/typing.py:1175(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:314(_is_owned)
#      4998    0.002    0.000    0.007    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/random.py:341(choice)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/json/__init__.py:183(dumps)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/json/encoder.py:105(__init__)
#         3    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:1533(enumerate)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:311(_acquire_restore)
#        24    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:1196(ident)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:601(is_set)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/threading.py:1220(is_alive)
#      9996    0.006    0.000    0.009    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/random.py:551(gauss)
#      4998    0.001    0.000    0.001    0.000 {built-in method math.cos}
#      9996    0.001    0.000    0.001    0.000 {built-in method math.log}
#      4998    0.000    0.000    0.000    0.000 {built-in method math.sin}
#      4998    0.000    0.000    0.000    0.000 {built-in method math.sqrt}
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/copy.py:252(<genexpr>)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/sugar/attrsettr.py:65(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/base_events.py:1893(_add_callback)
#      4998    0.001    0.000    0.002    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/random.py:494(uniform)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/base_events.py:538(_check_closed)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/events.py:36(__init__)
#        32    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/copy.py:172(_deepcopy_atomic)
#       2/1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/copy.py:217(_deepcopy_dict)
#         6    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/copy.py:231(_keep_alive)
#      4998    0.003    0.000    0.004    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/random.py:242(_randbelow_with_getrandbits)
#         7    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/base_events.py:732(time)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/base_events.py:741(call_later)
#         2    0.000    0.000    0.000    0.000 {method 'control' of 'select.kqueue' objects}
#     14994    0.001    0.000    0.001    0.000 {method 'random' of '_random.Random' objects}
#      9984    0.001    0.000    0.001    0.000 {method 'getrandbits' of '_random.Random' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/base_events.py:2003(get_debug)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/inspect.py:3254(bind)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/inspect.py:2782(name)
#        10    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/inspect.py:2794(kind)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/inspect.py:2874(__init__)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/inspect.py:3075(parameters)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/events.py:111(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/events.py:127(__lt__)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:675(sign)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:92(json_packer)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:649(msg)
#         4    0.000    0.000    0.000    0.000 {method 'update' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 {method 'copy' of '_hashlib.HMAC' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method now}
#         2    0.000    0.000    0.000    0.000 {method 'isoformat' of 'datetime.datetime' objects}
#         3    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/queue.py:97(empty)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:1523(notify_change)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/queue.py:209(_qsize)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:2635(validate)
#         1    0.000    0.000    0.004    0.004 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/tornado/ioloop.py:742(_run_callback)
#        21    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:1512(_notify_trait)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:281(extract_header)
#         3    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:718(_validate)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:198(utcnow)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:272(msg_header)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/tornado/ioloop.py:541(time)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/hmac.py:139(_current)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:3631(set)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/hmac.py:161(hexdigest)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:600(msg_id)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:645(msg_header)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/hmac.py:117(update)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/tornado/ioloop.py:596(call_later)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:566(sending)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:562(receiving)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:710(_update_handler)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/jsonutil.py:38(_ensure_tzinfo)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/dateutil/tz/tz.py:74(utcoffset)
#         2    0.000    0.000    0.013    0.006 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:580(_run_callback)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:687(_rebuild_io_state)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.013    0.007 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:607(_handle_events)
#         1    0.000    0.000    0.013    0.013 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:278(_really_send)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/decorator.py:199(fix)
#         1    0.000    0.000    0.005    0.005 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/decorator.py:229(fun)
#         1    0.000    0.000    0.002    0.002 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/IPython/core/history.py:54(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/IPython/core/history.py:824(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/IPython/core/history.py:830(_writeout_output_cache)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:259(schedule)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:710(_flush_buffers)
#         1    0.000    0.000    0.004    0.004 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:271(send_multipart)
#         2    0.000    0.000    0.013    0.006 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:157(_handle_event)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:718(_rotate_buffers)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:213(_is_master_process)
#         8    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:550(_is_master_process)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:725(_hooks)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:216(_check_mp_mode)
#         1    0.000    0.000    0.013    0.013 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:587(_schedule_in_thread)
#         8    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:577(_schedule_flush)
#         8    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:505(parent_header)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.004    0.004 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:616(_flush)
#         8    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/iostream.py:655(write)
#         6    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/ipykernel/ipkernel.py:770(_clean_thread_parent_frames)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/tornado/platform/asyncio.py:210(call_at)
#      5533    0.002    0.000    0.004    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:53(_wrapfunc)
#     14714    0.007    0.000    0.017    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/numerictypes.py:357(issubdtype)
#       535    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/numeric.py:274(full)
#         9    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:451(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/_ufunc_config.py:430(__enter__)
#      1070    0.002    0.000    0.002    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/numeric.py:136(ones)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/_ufunc_config.py:435(__exit__)
#         2    0.000    0.000    0.013    0.007 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/tornado/platform/asyncio.py:200(_handle_events)
#     40096    0.005    0.000    0.005    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:1980(shape)
#      1605    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/multiarray.py:153(concatenate)
#       535    0.000    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2322(any)
#      1070    0.000    0.000    0.002    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2421(all)
#      1393    0.001    0.000    0.006    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2692(max)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2836(min)
#      1691    0.001    0.000    0.005    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2979(prod)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:739(_extendLine)
#     14022    0.019    0.000    0.019    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:772(_check_bounds)
#     14022    0.017    0.000    0.043    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/scipy/_lib/_util.py:260(_asarray_validated)
#       535    0.000    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:1236(argmin)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/_ufunc_config.py:426(__init__)
#      4998    0.001    0.000    0.004    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:588(transpose)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:506(wrapper)
#       699    0.001    0.000    0.003    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2177(sum)
#      9005    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/multiarray.py:346(where)
#      1070    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/multiarray.py:741(dot)
#      1605    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/multiarray.py:1080(copyto)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/_ufunc_config.py:132(geterr)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:523(_array2string)
#     29428    0.005    0.000    0.009    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/numerictypes.py:283(issubclass_)
#         5    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:989(<genexpr>)
#         5    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:993(<genexpr>)
#         5    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:994(<genexpr>)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:1595(_array_str_implementation)
#      4998    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:584(_transpose_dispatcher)
#       535    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:1232(_argmin_dispatcher)
#     40096    0.002    0.000    0.002    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:1976(_shape_dispatcher)
#       699    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2172(_sum_dispatcher)
#       535    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2317(_any_dispatcher)
#      1070    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2416(_all_dispatcher)
#      1393    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2687(_max_dispatcher)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2831(_min_dispatcher)
#      1691    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2974(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:780(_formatArray)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:898(_none_or_positive_arg)
#     48437    0.006    0.000    0.050    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/_methods.py:47(_sum)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:411(<lambda>)
#     14022    0.002    0.000    0.003    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/lib/type_check.py:302(iscomplexobj)
#         5    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:984(<genexpr>)
#      5389    0.005    0.000    0.015    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/fromnumeric.py:71(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/_ufunc_config.py:33(seterr)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:64(_make_options_dict)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:403(_get_formatdict)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:561(array2string)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:753(_extendLine_pretty)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:907(__init__)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:1018(__call__)
#         1    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.generic' objects}
#      8805    0.004    0.000    0.012    0.000 {method 'sum' of 'numpy.generic' objects}
#         2    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#       535    0.000    0.000    0.000    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#     21546    0.009    0.000    0.009    0.000 {method 'dot' of 'numpy.ndarray' objects}
#     35568    0.006    0.000    0.006    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#     14022    0.003    0.000    0.003    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#     39632    0.010    0.000    0.051    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      4998    0.001    0.000    0.001    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#     66156    0.043    0.000    0.043    0.000 {built-in method numpy.array}
#     63884    0.011    0.000    0.011    0.000 {built-in method numpy.asarray}
#      4998    0.001    0.000    0.001    0.000 {built-in method numpy.zeros}
#      1605    0.001    0.000    0.001    0.000 {built-in method numpy.empty}
#         8    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
#     14022    0.005    0.000    0.005    0.000 {built-in method numpy.core._multiarray_umath.interp}
#         2    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#         4    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#     53826    0.052    0.000    0.052    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     48637    0.018    0.000    0.018    0.000 {method 'random' of 'numpy.random.mtrand.RandomState' objects}
#       692    0.008    0.000    0.010    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#     10915    0.014    0.000    0.014    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#     14022    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/lib/type_check.py:205(_is_type_dispatcher)
#     21546    0.003    0.000    0.004    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/linalg/linalg.py:140(isComplexType)
#     21546    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/linalg/linalg.py:2379(_norm_dispatcher)
#        70    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:606(__init__)
#     14022    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/lib/function_base.py:1457(_interp_dispatcher)
#     14022    0.002    0.000    0.003    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/ma/core.py:6485(isMaskedArray)
#        53    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:764(__init__)
#        10    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:857(__init__)
#     48366    0.006    0.000    0.006    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:90(aa)
#     48366    0.119    0.000    0.125    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:97(g2_elastic)
#       309    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:137(__init__)
#        84    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:514(__init__)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:452(_get_format_function)
#       5/1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:789(recurser)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/arrayprint.py:934(fillFormat)
#      1384    0.000    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/core/getlimits.py:484(__new__)
#     14022    0.006    0.000    0.028    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:684(_call_linear_np)
#     14022    0.009    0.000    0.058    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/scipy/interpolate/_interpolate.py:757(_evaluate)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:1527(_notify_observers)
#      4998    0.037    0.000    0.045    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/moliere.py:287(get_rotation_matrix)
#      4998    0.040    0.000    0.175    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/moliere.py:350(get_scattered_momentum_fast)
#         9    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/kinematics.py:271(annihilation_fourvecs)
#       309    0.003    0.000    0.004    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/kinematics.py:10(e_to_egamma_fourvecs)
#        84    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/kinematics.py:68(gamma_to_epem_fourvecs)
#        70    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/kinematics.py:102(compton_fourvecs)
#        63    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/kinematics.py:211(ee_to_ee_fourvecs)
#       535    0.166    0.000    2.098    0.004 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/shower.py:332(draw_sample)
#       692    0.019    0.000    2.143    0.003 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/shower.py:395(sample_scattering)
#       2/1    0.029    0.014    2.365    2.365 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/shower.py:531(generate_shower)
#       700    0.026    0.000    0.383    0.001 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/shower.py:437(propagate_particle)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:690(serialize)
#         1    0.000    0.000    0.002    0.002 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/IPython/core/history.py:836(writeout_cache)
#     14022    0.002    0.000    0.003    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/scipy/sparse/_base.py:1483(issparse)
#     14022    0.009    0.000    0.020    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/lib/function_base.py:1461(interp)
#        20    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/enum.py:1116(__new__)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/json/encoder.py:205(iterencode)
#      41/1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/copy.py:118(deepcopy)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/copy.py:247(_reconstruct)
#         4    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/sugar/attrsettr.py:42(__getattr__)
#         9    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/sugar/socket.py:621(send)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/sugar/socket.py:698(send_multipart)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/sugar/socket.py:777(recv_multipart)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/base_events.py:765(call_at)
#         3    0.000    0.000    0.017    0.006 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/events.py:86(_run)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/inspect.py:2935(apply_defaults)
#        21    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:629(get)
#         3    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:689(set)
#         3    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:2558(_validate_bounds)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/traitlets/traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.224    0.112 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/base_events.py:1908(_run_once)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/inspect.py:3119(_bind)
#         1    0.000    0.000    0.004    0.004 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/session.py:754(send)
#        94    0.002    0.000    0.002    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:775(__call__)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/selectors.py:558(select)
#         3    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/asyncio/selector_events.py:750(_process_events)
#         1    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/hmac.py:122(copy)
#         2    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/jupyter_client/jsonutil.py:107(json_default)
#         2    0.000    0.000    0.013    0.006 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:648(_handle_recv)
#     39561    1.602    0.000    1.807    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:148(__call__)
#        88    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:456(__call__)
#      8805    0.070    0.000    0.088    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:526(__call__)
#        71    0.002    0.000    0.002    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:619(__call__)
#        18    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/all_processes.py:868(__call__)
#     21546    0.026    0.000    0.050    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/numpy/linalg/linalg.py:2383(norm)
#     14022    0.003    0.000    0.006    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/scipy/interpolate/_polyint.py:96(_finish_y)
#     14022    0.008    0.000    0.122    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/scipy/interpolate/_polyint.py:59(__call__)
#     14022    0.005    0.000    0.050    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/scipy/interpolate/_polyint.py:90(_prepare_x)
#      1070    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:108(set_p0)
#      4998    0.012    0.000    0.012    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/moliere.py:209(get_chia_squared_alt)
#      4998    0.014    0.000    0.028    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:126(lose_energy)
#      4998    0.014    0.000    0.051    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/moliere.py:265(generate_moliere_angle_simplified_alt)
#      1070    0.002    0.000    0.007    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:36(__init__)
#       535    0.005    0.000    0.005    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:157(rotation_matrix)
#      5382    0.010    0.000    0.119    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/shower.py:308(get_mfp)
#      1771    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:145(set_ended)
#     23602    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:87(get_ids)
#      1070    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:106(set_mass)
#      2626    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:115(get_p0)
#     11052    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:117(set_pf)
#     29405    0.002    0.000    0.002    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:119(get_pf)
#      1070    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:136(set_r0)
#       854    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:138(get_r0)
#      6222    0.001    0.000    0.001    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:140(set_rf)
#      6768    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:142(get_rf)
#    260272    0.009    0.000    0.009    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:151(get_ended)
#       546    0.000    0.000    0.000    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/shower.py:178(get_material_properties)
#      4998    0.009    0.000    0.009    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/moliere.py:196(get_chic_squared_alt)
#      1070    0.002    0.000    0.004    0.000 /Users/kjkelly/miniforge3/envs/kjkvec/lib/python3.12/site-packages/PETITE/particle.py:80(set_ids)
#       2/1    0.000    0.000    2.589    2.589 /var/folders/8n/m3w03969119_28y6ndzhqp480000gp/T/ipykernel_34690/143096223.py:1(slowShower)

# %% [markdown]
# ## Tests and validations
#
# Generate some ensembles of brem./pair production samples, with 10 GeV particles injected and check basic properties of distributions

# %%
particle_dict_gamma = {'PID':22, 'ID':0, 'generation_number':0, 'generation_process':'Input'}
p0G = Particle([E0, 0, 0, E0], [0,0,0], particle_dict_gamma)

# %%
nSamp = 20000 # make this larger if you want more precision (it is slower though)...
s0 = np.array([sGraphite.sample_scattering(p0, process="Brem", VB=True) for i in tqdm(range(nSamp))])
s0G = np.array([sGraphite.sample_scattering(p0G, process="PairProd", VB=True) for i in tqdm(range(nSamp))])
# Out:
# 100%|██████████| 20000/20000 [14:48<00:00, 22.52it/s]
# 100%|██████████| 20000/20000 [00:18<00:00, 1066.07it/s]

# %%
Es = np.array([s[1].get_p0()[0] for s in s0])
EsE = np.array([s[0].get_p0()[0] for s in s0])

EsG = np.array([s[1].get_p0()[0] for s in s0G])
EsGP = np.array([s[0].get_p0()[0] for s in s0G])

# %% [markdown]
# ### Photon and electron distribution from first scatter
#
# We expect a flat photon distribution in log-space

# %%
b0 = np.logspace(-3, 1, 41)

dens = False
plt.hist(Es, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\mathrm{SM,\ Ryan\ Approach}$")
plt.hist(EsE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--')

plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_\gamma\ \mathrm{or}\ E_{e^-}\ [\mathrm{GeV}]$", fontsize=18)
plt.gca().set_ylabel(r"$\mathrm{particles/bin}$", fontsize=18)
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ### Look at angular distributions of outgoing particles from bremsstrahlung/pair production in terms of their $p_T/p_z$

# %%
pTpz = np.array([(s[1].get_p0()[3]/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0])
pTpzE = np.array([(s[0].get_p0()[3]/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0])

pTpzG = np.array([(s[1].get_p0()[3]/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0G])
pTpzGP = np.array([(s[0].get_p0()[3]/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0G])

# %%
pT = np.array([(1/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0])
pTE = np.array([(1/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0])

pTG = np.array([(1/np.sqrt(s[1].get_p0()[1]**2 + s[1].get_p0()[2]**2))**(-1) for s in s0G])
pTGP = np.array([(1/np.sqrt(s[0].get_p0()[1]**2 + s[0].get_p0()[2]**2))**(-1) for s in s0G])

# %%
b0 = np.logspace(-10, 2, 41)

dens = True
plt.hist(pTpz, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\gamma,\ \rm{brem.}$")
plt.hist(pTpzE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--', label=r"$e^{-},\ \rm{brem.}$")

plt.hist(pTpzG, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='-', label=r"$e^{-},\ \rm{pair\ prod.}$")
plt.hist(pTpzGP, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='--', label=r"$e^{+},\ \rm{pair\ prod.}$")

plt.gca().legend(loc='best', fontsize=14, framealpha=1.0)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$p_T/p_z$", fontsize=18)
plt.gca().set_ylabel(r"$dN/d(p_T/p_z)$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %%
b0 = np.logspace(-10, 2, 41)

dens = True
plt.hist(pT, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-', label=r"$\gamma,\ \rm{brem.}$")
plt.hist(pTE, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--', label=r"$e^{-},\ \rm{brem.}$")

plt.hist(pTG, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='-', label=r"$e^{-},\ \rm{pair\ prod.}$")
plt.hist(pTGP, bins=b0, histtype='step', lw=3, color='C4', density=dens, ls='--', label=r"$e^{+},\ \rm{pair\ prod.}$")

plt.gca().legend(loc='best', fontsize=14, framealpha=1.0)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$p_T\ [\mathrm{GeV}]$", fontsize=18)
plt.gca().set_ylabel(r"$dN/d(p_T)$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ## Outgoing electron/positron energies coming from pair production: should be identical

# %%
b0 = np.logspace(-4, 2, 41)

dens=False 

plt.hist(EsG, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='-')
plt.hist(EsGP, bins=b0, histtype='step', lw=3, color='C6', density=dens, ls='--')

#plt.gca().legend(loc=2, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_{e^\pm}\ [\mathrm{GeV}]$", fontsize=18)
plt.gca().set_ylabel(r"$\mathrm{photons/bin}$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]

set_size(5.0, 3.0)

# %% [markdown]
# ### Event-by-event ratio of $E_{e^-}/E_{e^+}$: should be symmetric about 1.

# %%
b0 = np.logspace(-4, 4, 61)

plt.hist(EsG/EsGP, bins=b0, histtype='step', lw=3, color='C6', density=False, ls='-', label=r"$\mathrm{SM,\ Ryan\ Approach}$")

#plt.gca().legend(loc=1, fontsize=16)
plt.gca().set_xscale('log')
plt.gca().set_yscale('log')
plt.gca().set_xlabel(r"$E_{e^-}/E_{e^+}$", fontsize=18)
plt.gca().set_ylabel(r"$\mathrm{simulations}$", fontsize=18)
#plt.gca().axis([1e-3,100,1e-11,1e-3])
[l.set_size(14) for l in plt.gca().get_xticklabels()]
[l.set_size(14) for l in plt.gca().get_yticklabels()]
plt.gca().axvline(1.0, color='k', lw=1, ls='--')

set_size(5.0, 3.0)

# %% [markdown]
# ### Asymmetry of the distribution.
#
# A basic test is distributions should be symmetric under  $e^+\leftrightarrow e^-$. We expect deviations due to statistical flucutations, on the order of $1/\sqrt{N}$ where $N$ is the size of the sample.

# %%
print("Asymmetry", (len(np.where(EsG > E0/2)[0]) - len(np.where(EsG < E0/2)[0]))/len(EsG) ) 
print("Statistical Error:" , 1/np.sqrt(len(EsG)) )
# Out:
# Asymmetry -0.0004
# Statistical Error: 0.007071067811865475
